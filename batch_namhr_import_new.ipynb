# %%
import pandas as pd
import pg8000
import psycopg2 as pq
import sqlalchemy as sa
from sqlalchemy import create_engine, ForeignKey, MetaData
from sqlalchemy import Column, Date, Integer, String, Table
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy.orm import relationship, backref
import peewee as pw
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from fuzzywuzzy.process import extract, extractBests,fuzz, itertools, extractOne
import etl  
from pprint import PrettyPrinter as Pretty
from collections import OrderedDict
import models
import postgresql as pqs
# Out:
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/fuzzywuzzy/fuzz.py:33: UserWarning: Using slow pure-python SequenceMatcher
#   warnings.warn('Using slow pure-python SequenceMatcher')

# %%
#open testing connection with py-postgresql
db = pqs.open('pq://vassr:bluedog@localhost:5432/vassr')

# %% [markdown]
# # Database Connection
# ____
#
#
# 1. Create connection to the database with SQLalchemy
# 2. Instantiates meta as the extracted metadata from the schema **"public"**
# 3. Autoreflects the tables found in public and turns them into classes.
#     - The scope of which tables are reflected is defined in **"working_tables"** variable
# 4. Instantiates the Base class as an automapped Base (instead of a Base where tables are declared, in "declarative_base")
# 5. Activates the Base (with Base.prepare())
# 6. Creates global class names based on their respective counterparts which have been autoreflected and turned into models taht live in **Base.classes**
# 7. Sets the database to autocommit, and autoflush.Since we are using the <code>"sesion.merge"</code> method, this is a convenience for now. Eventually we'll make it a bit more secure.

# %%
engine = create_engine('postgresql+pg8000://vassr:bluedog@localhost:5432/vassr')
meta = MetaData(schema="public")
Session = sa.orm.sessionmaker(bind=engine)
session = Session()
working_tables = ['person', 'location', 'condition_occurrence', 'care_site', 'observation', 'drug_exposure', 'test']
meta.reflect(engine, only=None)
Base = automap_base(metadata=meta)
Base.prepare()
Person, Condition, CareSite, Observation, DrugExposure, Location, Test = Base.classes.person, Base.classes.condition_occurrence, Base.classes.care_site, Base.classes.observation, Base.classes.drug_exposure, Base.classes.location, Base.classes.test
session.autocommit = False
session.autoflush = True

ins = sa.inspect(engine)

person = Person()
condition = Condition()
caresite = CareSite()
obs = Observation()
drugexp = DrugExposure()
location = Location()
test = Test()

'''

# Old Code:

Base = automap_base()
engine = create_engine('postgresql+pg8000://vassr:bluedog@localhost:5432/vassr')
Base.prepare(engine, reflect=True)
help(Base.prepare)
'''
'''
meta = MetaData(schema="public")

meta.reflect(bind=engine, schema='person', views=False, only=None, extend_existing=False, autoload_replace=True)

meta.create_all(bind=engine)
Base = automap_base(metadata=meta)
Session = sa.orm.sessionmaker()
Session.configure(bind=engine)
session = Session()
Base.prepare(engine, reflect=True)

'''
# Out:
# '\nmeta = MetaData(schema="public")\n\nmeta.reflect(bind=engine, schema=\'person\', views=False, only=None, extend_existing=False, autoload_replace=True)\n\nmeta.create_all(bind=engine)\nBase = automap_base(metadata=meta)\nSession = sa.orm.sessionmaker()\nSession.configure(bind=engine)\nsession = Session()\nBase.prepare(engine, reflect=True)\n\n'

# %%
session.flush()
g = Test()
g.gender_concept_id = 8507
g.person_source_value = 'rudy'
session.merge(g)

# %%
session.expunge_all()
session.flush()
session = Session()
doc = Test()
doc.person_source_value = 'rudy'
doc.emptydata = 'Now full'
query = session.query(Test).filter(Test.person_source_value == doc.person_source_value)

# %%
query.update(Test(person_source_value='rudy', emptydata='Now'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-881d3f3295ba> in <module>()
# ----> 1 query.update(Test(person_source_value='rudy', emptydata='Now'))
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/sqlalchemy/orm/query.py in update(self, values, synchronize_session)
#    2755         update_op = persistence.BulkUpdate.factory(
#    2756             self, synchronize_session, values)
# -> 2757         update_op.exec_()
#    2758         return update_op.rowcount
#    2759
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/sqlalchemy/orm/persistence.py in exec_(self)
#     894     def exec_(self):
#     895         self._do_pre()
# --> 896         self._do_pre_synchronize()
#     897         self._do_exec()
#     898         self._do_post_synchronize()
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/sqlalchemy/orm/persistence.py in _do_pre_synchronize(self)
#     943                     return True
#     944
# --> 945             self._additional_evaluators(evaluator_compiler)
#     946
#     947         except evaluator.UnevaluatableError:
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/sqlalchemy/orm/persistence.py in _additional_evaluators(self, evaluator_compiler)
#    1035     def _additional_evaluators(self, evaluator_compiler):
#    1036         self.value_evaluators = {}
# -> 1037         for key, value in self.values.items():
#    1038             key = _attr_as_key(key)
#    1039             self.value_evaluators[key] = evaluator_compiler.process(
#
# AttributeError: 'test' object has no attribute 'items'

# %%
#session.rollback()
#session.commit()
session.rollback()

# %%
@sa.event.listens_for(Table, "column_reflect")
def column_reflect(inspector, table, column_info):
    # set column.key = "attr_<lower_case_name>"
    column_info['key'] = "%s" % column_info['name'].lower()
    
class Peeps(Base):
    __table__ = Table("person", Base.metadata, autoload=True, autoload_with=engine)

# %%
doop = Peeps()

# %%
doop.metadata.
# Out:
# MetaData(bind=None)

# %%
# Configure Environment

pretty = Pretty(indent=1)
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
ihr.race.mapdict
# Out:
# {nan: 'null',
#  '7 Other': 'null',
#  '3 Asian ': 8515,
#  '5 American Indian/Alaskan Native': 8657,
#  '2 White': 'null',
#  '7 Other: Puerto Rican': 'null',
#  '1 White': 8527,
#  '2 Black/African American': 8516,
#  '6 Native Hawaiian/Pacific Islander': 8557,
#  '4 More than one race': 8522,
#  'Armenian': 'null',
#  '7 Other ': 8522,
#  '3 Asian': 'null'}

# %% [markdown]
# # Convience Lists

# %%
ins = sa.inspect(engine)
tablecheck = {}
for x in list(working_tables):
    for y in ins.get_columns(x):
        if y['name'] in list(tablecheck.keys()):
            print(y['name'] + " has duplicates")
            tablecheck[y['name']].append(str(x))
        else:
            tablecheck.update({y['name']:[str(x)]})
# Out:
# location_id has duplicates
# person_id has duplicates
# care_site_id has duplicates
# location_id has duplicates
# person_id has duplicates
# associated_provider_id has duplicates
# visit_occurrence_id has duplicates
# person_id has duplicates
# stop_reason has duplicates
# visit_occurrence_id has duplicates
# relevant_condition_concept_id has duplicates

# %% [markdown]
# # Classes

# %%
# 11/19/14 - TODO
# FIX POSTMAP
# Figure out object oriented alignment so each ELEMENT can update each field into omop. It could just be raw swl..

class Empty:
    pass

class Master(Empty):
    def __init__(self):
        self.name = "Master"

class Registry:
    '''Instantiate a registry for mapping. Only initiate with ready to go data. otherwise, work with IO object until properly formatted (headers in row 1, properly labeled index in first column, etc) '''
    reglist = []
    def __init__(self, regname, data, postmap = pd.DataFrame(), *args, **kwargs):
        self.regname = regname
        #exec("M.%s = self" % regname)
        self.data = pd.DataFrame(data)
        self.etlObjects = Empty()
        self.create_ids()
        try:
            self.data.to_sql(self.regname, engine, if_exists='replace', index=True, index_label='person_source_value')
        except: print("Regsitry instance %s created, but could not add it to database." % self.regname)
        self.postmap = pd.DataFrame()
        self.elements = []
        
    def init_elements(self, elementnames, **kwargs): 
        ''' Warning: **kwargs will apply to all element names in elementnames list, if you choose to run init_elements on a list of elementnames. It is best for initiating several elements that have similar characteristics.'''
        for x in list(elementnames):
            self.elements.append(x)
            print("Parsing " + x + "....")
            valueset = list(self.data[x].drop_duplicates().values)
            setattr(self, x, Element(x, valueset, self.data[x], self.regname))
            # exec("self.%s = Element('%s', valueset, self.data['%s'], self.regname)" % (x,x,x))
            #for key, value in kwargs.items():
             #   exec("self.%s.%s = '%s'" % (x, key, value))
              #  print("%s, %s" % (key,value))
            # exec("if self.%s.mappingtype == 'direct':" % x)
            # if self.Year_of_Birth.mappingtype == 'direct': 
            # exec("for value in self.%s.valueset:" % x)
            setattr(getattr(self, x), 'mapdict', {})
            for value in getattr(getattr(self, x), 'valueset'):
                print("Element = " + str(x) + ", Value = " + str(value))
                getattr(getattr(self, x), 'mapdict')[value] = None
                    
           # exec("M.masterplan[%s] = self.elements" % self.regname)
    def create_ids(self):
        '''creates a column with IDs conforming to GRDR standards'''
        source_tmp = input('Name of patient ID column in source data: ')
        source_id = closest_match(source_tmp, self.data.columns)
        guid = closest_match('GUID', self.data.columns)
        idcol = closest_match(source_id, self.data.columns)
        self.data['source_id_etl'] = self.data[idcol].apply(lambda x: str(str(self.regname) + '_' + str(x)))
        self.data['person_source_value'] = self.data[guid].fillna(self.data['source_id_etl']).str.replace(" ", "")
        self.person_source_value = self.data['person_source_value'].values
        self.data = self.data.set_index('person_source_value')
        return self.data
    
        self.datadict = {}
        for x in self.elements:
            self.datadict[x] = list(self.data[x].drop_duplicates().values)
        Registry.reglist.append(self.regname)
    def __repr__(self):
        return "< Registry '%s' >" % self.regname
    


# In[4]:

class Element:
    def __init__(self, elementname, valueset, data, regname, mappingtype='', mappingstatus='Premap', mapdict={}, postmap = pd.DataFrame(), target_table='Not yet specified', target_field='Not yet specified',  *args, **kwargs):
        self.elementname = elementname
        self.regname = regname # source registry name
        self.sourcefield = elementname # source column
        self.valueset = list(valueset) # source value
        self.postmap = postmap
        self.data = data
        self.mappingtype = mappingtype
        self.mappingstatus = mappingstatus
        self.mapdict = mapdict
        self.target_table = target_table
        self.target_field = target_field
    def mapper(self, x):
            try:
                return self.mapdict[closest_match(x, list(str(x) for x in self.mapdict.keys()))]
            except: return None
    def transform(self):
        # Where x is the each value of the original data, look up the value for key x in Element.mapdict
        #self.target_table = input("What is the target table name?")
        self.target_field = input("What is the target field?")
        self.source_field = input("Name of omop source (eg condition_source_value)?")
        # type_concept_field = input("Name of omop type concept (eg condition_type_concept_id)?")
        self.postmap[self.target_field] = self.data.apply(self.mapper)
        self.postmap = self.postmap.rename(columns = {self.elementname: self.target_field})
        self.postmap[self.source_field] = self.data
        setattr(self,'mappingstatus', 'Postmap')
        # df_new = pd.DataFrame(self.postmap).rename(columns={self.elementname: self.target_field})
        # self.postmap = df_new
        #getattr(getattr(self, regname), 'postmap')[self.target_field] = getattr(self, 'postmap')
        #exec("%s.postmap = pd.concat([%s.postmap, self.postmap], axis=1)" % (self.regname, self.regname))
        print('Mapped %s: type = %s, target_table = %s, target_field = %s' %  (self.elementname, self.mappingtype, self.target_table, self.target_field)) 
        return self.postmap.astype(object).where(pd.notnull(self.postmap), None)

    def direct_transform(self):
        for x in self.data.iteritems():
            if is_year(x):
                #pd.DataFrame(self.data * self.data.apply(is_year)).apply(pd.to_datetime, infer_datetime_format=True, format='%Y')
                self.data = ihr.dx_date.data.apply(pd.to_datetime, infer_datetime_format=True, format='%Y')
        return self.data
      
        self.postmap[self.target_field] = pd.DataFrame(self.data)
    def __repr__(self):
        classrep = " %s.%s <class Element>" % (self.regname, self.sourcefield)
        print(" regname = '%s',\n elementname = '%s',\n sourcefield = '%s'" % (self.regname, self.elementname, self.sourcefield))
        if self.regname not in Registry.reglist:
            return "%s \n Warning: Origin name %s not an instantiated Registry" % (classrep, self.regname)
        else: return classrep 

# This amazing piece of programming will automatically map freetext into an omop concept id. Use if there is a lot of freetext.
default_target = 'GRDR_Mapping_11_13_14.xlsx'
class Mapper:
    def __init__(self, regobject, sheetname, target_file=default_target):
        self.regobject = regobject
        self.sheetname = sheetname
        self.target_file = target_file
        self.mapdf = pd.read_excel(target_file, sheetname=self.sheetname)
        self.regobject.mapdf = self.mapdf
        for x in range(0, len(self.mapdf)):
            value = self.mapdf.ix[x]['source_code']
            if type(value)==int and value in range(0,10):
                self.mapdf.loc[x, 'source_code'] = "%s %s" % (value, self.mapdf.loc[x, 'source_value'])
                #mapping['source_code'] + ' ' + mapping['source_value']
        self.mapmaster = self.mapdf.to_dict(orient="records")
        self.mapkeys = list(self.mapmaster[0].keys())
        
    def check_fields(self):
        self.goodfields = []
        count = 0
        for x in self.mapdf['field name'].dropna():
            if x in self.regobject.data.columns:
                print(x)
                self.goodfields.append(x)
                count +=1 
        print(str(count) + " fields extracted from the mapping table.")
        return self.goodfields
 
    def map_all(self):
        '''
       Map_all has a confusing array of variables. 
       - "mapkeys" are the columns of a mapping file. these are boilerplate -- 'field name', 'source code', 'source value', etc.
       - "mapdict_of_element" is the "mapdict" attribute of each Element object. so for ihr.race.mapdict, ihr is the registry, race is the element, and mapdict is the dictionary of valueset value to target mapping.'
       - "mapdict_of_element_keys" is a conveninence list that contains the KEYS of mapdict_of_element SANS all nan values. nan values trip up the fuzzy matching algorithm (extractOne), and it is definitely more valuable ot have that algorithm."
        '''
        for x in self.mapmaster:
            if x[closest_match('field_name', self.mapkeys)] in self.regobject.elements:
                
                mapdict_of_element= getattr(getattr(self.regobject, x['field name']), 'mapdict')
                mapdict_of_element_keys = [x for x in mapdict_of_element.keys() if str(x) != 'nan']
                print(mapdict_of_element)
                self.mapmaster[0][closest_match('yes', self.mapkeys)]

                code = x[closest_match('source_code', self.mapkeys)]
                value = x[closest_match('source_value', self.mapkeys)]
                try:
                    if process.extractOne(str(code),  mapdict_of_element_keys)[1] > 50:
                        try:
                            mapdict_of_element[code] = x[closest_match('omop_concept_id', self.mapkeys)]
                        except: handle_it()
                    else:
                        if process.extractOne(str(value),  mapdict_of_element_keys)[1] > 50:
                            try:
                                mapdict_of_element[value] = x[closest_match('omop_concept_id', self.mapkeys)]
                            except: handle_it()
                        print(str(x['field name']) + ", " + str(code) + " cannot be mapped")
                except:
                    handle_it()

class AutoMapper:
    def __init__(self, regobject):
        from algoliasearch import algoliasearch as ag
        self.client = ag.Client("31K5UZ93QX", "3fad605ef37e555d88993865e467f2a2")
        self.index = client.init_index('omop_concepts')
        self.regobject = regobject
        dic = {}

    # Alter this line right here to add the appropriate "unmappable" to be mapped. Also switch snomed to RxNorm, etc as appropriate
    def automap(self, element):
        for x in getattr(getattr(self.regobject, element), 'valueset'):
            try:
                length = len(x)
            except:
                next
            if len(x) > 1 and type(x) != int:
                res = self.index.search("\SNOMED\\ '%s'" % x, {"removeWordsIfNoResults":"firstWords", "facets":"CONCEPT_CLASS_ID", "facetFilters": "CONCEPT_CLASS_ID:Clinical Finding"})
                try:
                    result = int(res['hits'][0]['objectID'])
                except: pass
                ihr.dxc_secondaryto.mapdict[x] = result



class DBLoader:
    def __init__(self, db, registry, target_table, target_field='NO_FIELD'):
        self.db = db
        self.registry = registry
        self.target_table = target_table
        self.target_field = target_field
        self.data = registry.data
        self.insert_id = db.prepare("insert into person (person_source_value) select $1 AS varchar WHERE NOT EXISTS (SELECT 1 FROM person WHERE person_source_value like '$1')")
        self.clean_duplicates = db.prepare("""
               DELETE FROM person USING person p2
              WHERE person.person_source_value = p2.person_source_value AND person.person_id < p2.person_id;
              """)
    def insert_all_ids(self):
        for x in self.data.index:
            try:
                self.insert_id(str(x))
                self.clean_duplicates()
                print("Added " + str(x) + " to vassr.public.person.person_source_value")
            except Exception:
               print(handle_it())
    def update_all(self):
        cols = list(self.registry.postmap.columns)
        for x in self.registry.postmap.dropna().index:
            print(x)
            row = self.registry.postmap.dropna().ix[x]
            rowdict = row.to_dict()
            self.target_field = cols[0]
            for col in cols:
                self.target_field = col
                typer = db.prepare("select data_type from information_schema.columns  where table_name = '%s' and column_name = '%s'" % (self.target_table, self.target_field))
                v1 = typer()[0][0]
                if rowdict[col] != '':
                    print("col = " + str(col) + ", rowdict[col] = " + str(rowdict[col]))
                    ins = db.prepare("update %s set %s = (select '%s'::%s) where person_source_value::text like '%s';" % (self.target_table, self.target_field,str(rowdict[col]), v1, x))
                    ins()
        return pd.read_sql_table(self.target_table, engine)

# %% [markdown]
# # Convenience Functions

# %%
# Convenience functions
    
def handle_it():
    import sys
    e = sys.exc_info()[1]
    return e.args[0]


def is_year(x):
    if len(str(x)) == 4:
        if str(x)[:2] == '19' or  str(x)[:2] == '20':
            try:
                year = int(x)
            except:
                print("Looks like a year, but doesn't act like  one. Not budging to integer.")
        return True
    else: return False
    
def to_year(x):
    '''x needs to be an Element'''
    
    data = getattr(x, 'data')
    data.apply(pd.to_datetime, infer_datetime_format=True, format='%Y')

def reset(name_of_reg, target_file):
    ''' name_of_reg is three letter name. be SURE to also set the object variable to this same three letter name as well, as a convention. data is the registries flatfile.'''
    temp_reg = etl.Registry('name_of_reg', pd.read_sql_table(name_of_reg, engine, schema='sourcedata'))
    temp_reg.init_elements(checked)
    return temp_reg

def clean_mapper(mapping):
    lis = []
    for x in range(0, len(mapping)):
        value = mapping.ix[x]['source_code']
        if type(value)==int and value in range(0,10):
            mapping.loc[x, 'source_code'] = "%s %s" % (value, mapping.loc[x, 'source_value'])
            #mapping['source_code'] + ' ' + mapping['source_value']
    mapping = mapping
    return mapping

def map_it():
    for x in ihr.mapmaster:
        if x['field name'] in ihr.elements:
            mapitem = getattr(getattr(ihr, x['field name']), 'mapdict')
            print(mapitem)
            code = x['source_code']
            value = x['source_value']
            if process.extractOne(code, list(mapitem.keys()))[1] > 50:
                try:
                    mapitem[code] = x['OMOP_ Concept_ID']
                except: pass
            else:
                if process.extractOne(value, list(mapitem.keys()))[1] > 50:
                    try:
                        mapitem[value] = x['OMOP_ Concept_ID']
                    except: pass
            if code not in mapitem.keys() and value not in mapitem.keys():
                print(str(x['field name']) + ", " + str(code) + " cannot be mapped")

def closest_match(x, choices):
    if str(x) == 'NaN':
        return 'null'
    else: match = extractOne(x, choices)
    return match[0]
get_column = lambda x: closest_match(x, tablecheck.keys())[0]
get_table = lambda x: tablecheck[get_column(x)]
id_lookup = lambda x: int(pd.read_sql_query('select person_id, person_source_value from person;', engine).set_index('person_source_value').loc[x].values[0])

# %%
person_staging = pd.read_sql_table('person', engine)

# %%
M = Master()
ihr = Registry('ihr', pd.read_csv('namhr/current_data/csv/20141029MHRegsitry.csv'))
M.ihr = ihr
ihr_map = Mapper(ihr,  '')
checkfields = ihr_map.check_fields()
checked = ['race', 'sex', 'ethnic', 'education', 'employment', 'dx_date', 'diamox', 'lasix', 'topamax', 'neptazane', 'dxc_confirm','dxc_diagnosis','dxc_secondaryto', 'dxc_reviewdate']
#ihr = reset('ihr', 'ihr/current_data/csv/ihr_complete.csv')
ihr.init_elements(checked)
ihr.sex.mapdict['Male'] = 8507
ihr.sex.mapdict['Female'] = 8532

ihr_map.map_all()
ihr.ethnic.mapdict.pop('Hispanic or Latino')
ihr.ethnic.mapdict.pop('Non-Hispanic or Latino')
ihr.datadictmap = {}
for x in ihr.elements:
    ihr.datadictmap[x] = getattr(getattr(ihr, x), 'postmap')
# Out:
# Name of patient ID column in source data: Registry Patienet Unique ID
# race
# race
# race
# race
# race
# race
# race
# ethnic
# ethnic
# education
# education
# education
# education
# education
# education
# education
# education
# education
# education
# education
# education
# education
# employment
# employment
# employment
# employment
# employment
# employment
# dx_date
# shunt
# shunt_num
# shunt_lp
# shunt_vp
# shunt_va
# subtemp
# cranialvault
# onsd
# onsd_side
# diamox
# diamox
# lasix
# lasix
# topamax
# topamax
# neptazane
# neptazane
# dxc_ha
# dxc_tvo
# dxc_blurred
# dxc_tinn
# dxc_diplopia
# dxc_neck
# dxc_arthralgias
# dxc_ataxia
# dxc_facepalsy
# dxc_radicular
# dxc_pap
# dxc_pap_bilat
# dxc_pap_unilat
# dxc_visualacuity
# dxc_perimetry
# dxc_6thnerve
# dxc_emptysella
# dxc_flatglobe
# dxc_peridis
# dxc_other
# dxc_otherspecify
# dxc_lp1_op
# dxc_lp1_date
# dxc_lp1_position
# dxc_lp2_op
# dxc_lp2_date
# dxc_lp2_position
# dxc_lp3_op
# dxc_lp3_date
# dxc_lp3_position
# dxc_lp4_op
# dxc_lp4_date
# dxc_lp4_position
# dxc_diagnosis
# dxc_confirm
# dxc_secondaryto
# dxc_reviewdate
# dxc_surgnotes
# 84 fields extracted from the mapping table.
# Parsing race....
# Element = race, Value = nan
# Element = race, Value = 1 White
# Element = race, Value = 2 Black/African American
# Element = race, Value = Armenian
# Element = race, Value = 5 American Indian/Alaskan Native
# Element = race, Value = 7 Other: Puerto Rican
# Element = race, Value = 4 More than one race
# Element = race, Value = 7 Other
# Element = race, Value = 3 Asian
# Element = race, Value = 2 White
# Parsing sex....
# Element = sex, Value = Female
# Element = sex, Value = Male
# Parsing ethnic....
# Element = ethnic, Value = Non-Hispanic or Latino
# Element = ethnic, Value = Hispanic or Latino
# Element = ethnic, Value = Unknown/No answer
# Parsing education....
# Element = education, Value = nan
# Element = education, Value = Trade School
# Element = education, Value = Junior High School
# Element = education, Value = Other
# Element = education, Value = College
# Element = education, Value = Some College
# Element = education, Value = High School
# Element = education, Value = Graduate School
# Element = education, Value = Less than High School
# Element = education, Value = Associates Degree (2 years)
# Element = education, Value = Elementary School
# Element = education, Value = Trade School/ Some College
# Element = education, Value = Preschool
# Element = education, Value = Technicial School
# Element = education, Value = Vocational School
# Element = education, Value = Trade/Technical/Vocational Scho
# Parsing employment....
# Element = employment, Value = nan
# Element = employment, Value = 5 Disabled
# Element = employment, Value = 1 Full-Time
# Element = employment, Value = 3 Retired
# Element = employment, Value = 4 Unemployed
# Element = employment, Value = 2 Part-Time
# Element = employment, Value = 6 Other
# Element = employment, Value = Full-time Student
# Parsing dx_date....
# Element = dx_date, Value = 2002
# Element = dx_date, Value = 2001
# Element = dx_date, Value = 1997
# Element = dx_date, Value = 2003
# Element = dx_date, Value = 1995
# Element = dx_date, Value = 2000
# Element = dx_date, Value = 1999
# Element = dx_date, Value = 1996
# Element = dx_date, Value = 1998
# Element = dx_date, Value = 1994
# Element = dx_date, Value = 1993
# Element = dx_date, Value = 1987
# Element = dx_date, Value = 1992
# Element = dx_date, Value = 1990
# Element = dx_date, Value = 1991
# Element = dx_date, Value = 1989
# Element = dx_date, Value = 300
# Element = dx_date, Value = 1986
# Element = dx_date, Value = 2004
# Element = dx_date, Value = 1985
# Element = dx_date, Value = 1976
# Element = dx_date, Value = 1982
# Element = dx_date, Value = 1983
# Element = dx_date, Value = 1981
# Element = dx_date, Value = 1988
# Element = dx_date, Value = 1974
# Element = dx_date, Value = 2005
# Element = dx_date, Value = 1984
# Element = dx_date, Value = 1980
# Element = dx_date, Value = 1969
# Element = dx_date, Value = 2006
# Element = dx_date, Value = 2007
# Element = dx_date, Value = 1978
# Element = dx_date, Value = 2008
# Element = dx_date, Value = 2009
# Element = dx_date, Value = 2010
# Element = dx_date, Value = 2011
# Element = dx_date, Value = 2012
# Element = dx_date, Value = 2013
# Parsing diamox....
# Element = diamox, Value = Missing
# Element = diamox, Value = nan
# Element = diamox, Value = 1 Yes
# Element = diamox, Value = 2 No
# Parsing lasix....
# Element = lasix, Value = Missing
# Element = lasix, Value = 1 Yes
# Element = lasix, Value = 2 No
# Element = lasix, Value = nan
# Parsing topamax....
# Element = topamax, Value = Missing
# Element = topamax, Value = nan
# Element = topamax, Value = 1 Yes
# Element = topamax, Value = 2 No
# Parsing neptazane....
# Element = neptazane, Value = Missing
# Element = neptazane, Value = nan
# Element = neptazane, Value = 2 No
# Element = neptazane, Value = 1 Yes
# Parsing dxc_confirm....
# Element = dxc_confirm, Value = Confirmed IH
# Parsing dxc_diagnosis....
# Element = dxc_diagnosis, Value = 1 Primary
# Element = dxc_diagnosis, Value = 2 Secondary
# Element = dxc_diagnosis, Value = 3 Undetermined
# Parsing dxc_secondaryto....
# Element = dxc_secondaryto, Value = .
# Element = dxc_secondaryto, Value = MINOCYCLINE
# Element = dxc_secondaryto, Value = VIRAL MENINGITIS
# Element = dxc_secondaryto, Value = VENOUS OBSTRUCTIVE DISEASE
# Element = dxc_secondaryto, Value = TETRACYCLINE
# Element = dxc_secondaryto, Value = SLEEP APNEA
# Element = dxc_secondaryto, Value = DOXYCYCLINE
# Element = dxc_secondaryto, Value = VIRAL OR AUTOIMMUNE MENINGITIS
# Element = dxc_secondaryto, Value = CUSHING SYNDROME (RX SURGICAL RESECTION FOR ADRENAL TUMOR)
# Element = dxc_secondaryto, Value = Chiari Malformation
# Element = dxc_secondaryto, Value = HYPERTHYROIDISM
# Element = dxc_secondaryto, Value = NEUROSYPHILIS AND MENINGITIS
# Element = dxc_secondaryto, Value = MENINGITIS; LIVER FAILURE
# Element = dxc_secondaryto, Value = PRIMARY SJOGREN'S SYNDROME, CNS VASCULITIS
# Element = dxc_secondaryto, Value = CEREBRAL VENOUS STENOSIS
# Element = dxc_secondaryto, Value = CEREBRAL VENOUS THROMBOSIS
# Element = dxc_secondaryto, Value = Minocycline
# Element = dxc_secondaryto, Value = SARCOIDOSIS VS DEMYLINATING DISEASE
# Element = dxc_secondaryto, Value = ARNOLD CHIARI MALFORMATION TYPE I
# Element = dxc_secondaryto, Value = Chiari
# Element = dxc_secondaryto, Value = OPTIC NERVE GLIOMA
# Element = dxc_secondaryto, Value = SUBDURAL HEMATOMA
# Element = dxc_secondaryto, Value = VIRAL MENINGITIS- RECURRENT
# Element = dxc_secondaryto, Value = AMIODARONE
# Element = dxc_secondaryto, Value = SARCOIDOSIS
# Element = dxc_secondaryto, Value = HEAD TRAUMA
# Element = dxc_secondaryto, Value = Mononucleous and strep
# Element = dxc_secondaryto, Value = CHIARI MALFORMATION
# Element = dxc_secondaryto, Value = AMIODARONE (DRUG)
# Element = dxc_secondaryto, Value = MENINGITIS; INTERFERON RX
# Element = dxc_secondaryto, Value = NEUROFIBROMATOSIS
# Element = dxc_secondaryto, Value = TOXIC SOLVENTS
# Element = dxc_secondaryto, Value = POSSIBLY TETRACYCLINE AND LITHIUM
# Element = dxc_secondaryto, Value = LEUKEMIA
# Element = dxc_secondaryto, Value = POSSIBLY LUPUS
# Element = dxc_secondaryto, Value = NEUROSURGERY ACCOUSTIC NEUROMA REMOVAL
# Element = dxc_secondaryto, Value = BEHCET'S DISEASE[
# Element = dxc_secondaryto, Value = INTRACRANIAL SURGERY
# Element = dxc_secondaryto, Value = nan
# Element = dxc_secondaryto, Value = EXPOSURE TO HYDROCARBONS
# Element = dxc_secondaryto, Value = Lumbar spinal stenosis
# Element = dxc_secondaryto, Value = MENINGIOMA OF SPHENOID WING AND OPTIC NERVE SHEATHS
# Element = dxc_secondaryto, Value = OBSTRUCTION TYPE HYDROCEPHALUS, BLOCKED AT AQUEDUCT
# Element = dxc_secondaryto, Value = POSSIBLY MINOCYCLINE
# Element = dxc_secondaryto, Value = SPINAL ARACHNOID CYST
# Element = dxc_secondaryto, Value = TEMPORAL FOSSA ARACHNOID CYST
# Element = dxc_secondaryto, Value = RIGHT TRANSVERSE SINUS THROMBOSIS
# Element = dxc_secondaryto, Value = ATRA (ALL TRANS RETONOIC ACID) FOR ACUTE/PROMYELOCYTIC LEUKEMIA
# Element = dxc_secondaryto, Value = INTRATHECAL CHEMOTHERAPY FOR LEUKEMIA
# Element = dxc_secondaryto, Value = Right Venous Sinus Thrombosis
# Element = dxc_secondaryto, Value = MRV- OCCLUDED VENOUS SINUS OS
# Element = dxc_secondaryto, Value = Guillian-Barre Syndrome
# Element = dxc_secondaryto, Value = TETRACYCLINE AND VITAMIN A.
# Element = dxc_secondaryto, Value = ARNOLD CHIARI MALFORMATION
# Element = dxc_secondaryto, Value = Accutane
# Element = dxc_secondaryto, Value = LYME DISEASE
# Element = dxc_secondaryto, Value = ARNOLD CHIARI/INTRATHECAL METHOTREXATE FOR LEUKEMIA
# Element = dxc_secondaryto, Value = LUPUS, MENINGITIS SECONDARY TO SPHENOID SURGERY (PITUITARY TUMOR)- CSF LEAK
# Element = dxc_secondaryto, Value = Possible reaction to prednisone/antibiotics for sinusitis
# Element = dxc_secondaryto, Value = Cystinosis
# Element = dxc_secondaryto, Value = CHIARI I MALFORMATION
# Element = dxc_secondaryto, Value = BRAIN TUMOR
# Element = dxc_secondaryto, Value = CHIARI DECOMPRESSION 2000
# Element = dxc_secondaryto, Value =  MINOCYCLINE
# Element = dxc_secondaryto, Value = RIGHT LATERAL SINUS THROMBOSIS AND SAGGITAL SINUS COAGULOPATHY
# Element = dxc_secondaryto, Value = HX OF VENOUS SINUS THROMBOSIS; SAGITTAL SINUS THROMBOSIS
# Element = dxc_secondaryto, Value = CUSHING SYNDROME
# Element = dxc_secondaryto, Value = VENOUS HYPERTENSION FROM DURAL A-V FISTULA
# Element = dxc_secondaryto, Value = LEFT LATERAL SINUS OBSTRUCTION
# Element = dxc_secondaryto, Value = ENCEPHALITIS
# Element = dxc_secondaryto, Value = LEFT THROMBOSIS OF CEREBRAL VENOUS SINUSES
# Element = dxc_secondaryto, Value = CEREBRAL VENOUS SINUS THROMBOSIS
# Element = dxc_secondaryto, Value = DURAL SAGITTAL VENOUS THROMBOSIS
# Element = dxc_secondaryto, Value = LITHIUM
# Element = dxc_secondaryto, Value = CEREBRAL VENOUS SINUS STENOSIS BILATERAL
# Element = dxc_secondaryto, Value = SAGITTAL SINUS THROMBOSIS
# Element = dxc_secondaryto, Value = BILATERAL TRANSVERSE SINUS STENOSIS
# Element = dxc_secondaryto, Value = 1 DURAL SINUS THROMBOSIS; 2 DURAL AV FISTULA
# Element = dxc_secondaryto, Value = Hashimoto Thyroiditis (Hypothyroidism)
# Element = dxc_secondaryto, Value = Venous Sinus Hypertension; Radical Mastoidectomy
# Element = dxc_secondaryto, Value = MENINGITIS
# Element = dxc_secondaryto, Value = LYME DISEASE; HYPOTHYROIDISM
# Element = dxc_secondaryto, Value = Minocycline and Cerebral Venous Thrombosis
# Element = dxc_secondaryto, Value = Stenosis of Transverse Sinus
# Element = dxc_secondaryto, Value = THROMBOPHLEBITIS OF CEREBRAL SINUS
# Element = dxc_secondaryto, Value = Aqueductal Stenosis (producing non-communicating hydrocehalus possibly related to head trauma
# Element = dxc_secondaryto, Value = SUPERIOR SAGGITAL SINUS THROMBOSIS (CEREBRAL VENOUS)
# Element = dxc_secondaryto, Value = CEREBRAL VENOUS SINUS STENOSIS
# Element = dxc_secondaryto, Value = RAMSAY HUNT SYNDROME (HERPATIC)
# Element = dxc_secondaryto, Value = Bilateral Severe Transverse Sinus Stenosis and Bilateral Cavernous Sinus Thrombosis
# Element = dxc_secondaryto, Value = Chiari Malformation Type 1
# Element = dxc_secondaryto, Value = BACTRIM
# Element = dxc_secondaryto, Value = Intracranial surgery and radiation, pituitary and adrenals
# Element = dxc_secondaryto, Value = Cerebral Venous Stenosis of the Left Transverse Sinus
# Element = dxc_secondaryto, Value = Cerebral venous sinuses thrombosis
# Element = dxc_secondaryto, Value = Transverse Sinus Stenosis
# Element = dxc_secondaryto, Value = ADRENOLEUKODYSTROPHY (ALD)
# Element = dxc_secondaryto, Value = Bilateral Transverse Sinus Stenosis
# Element = dxc_secondaryto, Value = Stenosis of Transverse Sinuses
# Element = dxc_secondaryto, Value = Cerebral Transverse Sinus Stenosis
# Element = dxc_secondaryto, Value = Cerebral Venous Thrombosis
# Element = dxc_secondaryto, Value = Thrombosis of the Cerebral Sinus
# Element = dxc_secondaryto, Value = Cerebral Venous Transverse Sinus Stenosis L+R
# Element = dxc_secondaryto, Value = Traumatic Brain Injury, Chronic Thrombosis of Sagittal Sinus
# Parsing dxc_reviewdate....
# Element = dxc_reviewdate, Value = 2006.0
# Element = dxc_reviewdate, Value = 2005.0
# Element = dxc_reviewdate, Value = 2009.0
# Element = dxc_reviewdate, Value = 2007.0
# Element = dxc_reviewdate, Value = 2008.0
# Element = dxc_reviewdate, Value = 2012.0
# Element = dxc_reviewdate, Value = 2013.0
# Element = dxc_reviewdate, Value = 2010.0
# Element = dxc_reviewdate, Value = 2011.0
# Element = dxc_reviewdate, Value = nan
# Element = dxc_reviewdate, Value = 2014.0
# {nan: None, '7 Other: Puerto Rican': None, '1 White': None, '7 Other': None, '2 Black/African American': None, 'Armenian': None, '3 Asian': None, '5 American Indian/Alaskan Native': None, '2 White': None, '4 More than one race': None}
# {nan: None, '7 Other: Puerto Rican': None, '1 White': 8527, '7 Other': None, '2 Black/African American': None, 'Armenian': None, '3 Asian': None, '5 American Indian/Alaskan Native': None, '2 White': None, '4 More than one race': None}
# {nan: None, '7 Other: Puerto Rican': None, '1 White': 8527, '7 Other': None, '2 Black/African American': 8516, 'Armenian': None, '3 Asian': None, '5 American Indian/Alaskan Native': None, '2 White': None, '4 More than one race': None}
# {nan: None, '7 Other: Puerto Rican': None, '1 White': 8527, '7 Other': None, '3 Asian ': 8515, '2 Black/African American': 8516, 'Armenian': None, '3 Asian': None, '5 American Indian/Alaskan Native': None, '2 White': None, '4 More than one race': None}
# {nan: None, '7 Other: Puerto Rican': None, '1 White': 8527, '7 Other': None, '3 Asian ': 8515, '2 Black/African American': 8516, 'Armenian': None, '3 Asian': None, '5 American Indian/Alaskan Native': None, '2 White': None, '4 More than one race': 8522}
# {nan: None, '7 Other: Puerto Rican': None, '1 White': 8527, '7 Other': None, '3 Asian ': 8515, '2 Black/African American': 8516, 'Armenian': None, '3 Asian': None, '5 American Indian/Alaskan Native': 8657, '2 White': None, '4 More than one race': 8522}
# {nan: None, '1 White': 8527, '2 White': None, '3 Asian ': 8515, '3 Asian': None, '4 More than one race': 8522, '6 Native Hawaiian/Pacific Islander': 8557, '7 Other: Puerto Rican': None, '7 Other': None, 'Armenian': None, '2 Black/African American': 8516, '5 American Indian/Alaskan Native': 8657}
# {'Hispanic or Latino': None, 'Non-Hispanic or Latino': None, 'Unknown/No answer': None}
# {'1 Hispanic/Latino': 38003563, 'Hispanic or Latino': None, 'Non-Hispanic or Latino': None, 'Unknown/No answer': None}
# {nan: None, 'Trade/Technical/Vocational Scho': None, 'Trade School/ Some College': None, 'Other': None, 'Less than High School': None, 'Trade School': None, 'Associates Degree (2 years)': None, 'College': None, 'Vocational School': None, 'High School': None, 'Preschool': None, 'Junior High School': None, 'Graduate School': None, 'Technicial School': None, 'Elementary School': None, 'Some College': None}
# {nan: 43022063, 'Trade/Technical/Vocational Scho': None, 'Trade School/ Some College': None, 'Other': None, 'Less than High School': None, 'Trade School': None, 'Associates Degree (2 years)': None, 'College': None, 'Vocational School': None, 'High School': None, 'Preschool': None, 'Junior High School': None, 'Graduate School': None, 'Technicial School': None, 'Elementary School': None, 'Some College': None}
METHOTREXATE FOR LEUKEMIA': None, 'SUPERIOR SAGGITAL SINUS THROMBOSIS (CEREBRAL VENOUS)': None, 'CEREBRAL VENOUS STENOSIS': None, 'CUSHING SYNDROME (RX SURGICAL RESECTION FOR ADRENAL TUMOR)': None, 'Chiari': None, 'Right Venous Sinus Thrombosis': None, 'LITHIUM': None, 'CEREBRAL VENOUS THROMBOSIS': None, 'MINOCYCLINE': None, 'Minocycline and Cerebral Venous Thrombosis': None, 'EXPOSURE TO HYDROCARBONS': None, 'SLEEP APNEA': None, 'Bilateral Severe Transverse Sinus Stenosis and Bilateral Cavernous Sinus Thrombosis': None, 'ATRA (ALL TRANS RETONOIC ACID) FOR ACUTE/PROMYELOCYTIC LEUKEMIA': None, 'Transverse Sinus Stenosis': None, '.': None, 'RIGHT TRANSVERSE SINUS THROMBOSIS': None, 'Intracranial surgery and radiation, pituitary and adrenals': None, 'Chiari Malformation': None, 'POSSIBLY TETRACYCLINE AND LITHIUM': None, 'Stenosis of Transverse Sinuses': None, 'ARNOLD CHIARI MALFORMATION TYPE I': None, 'CEREBRAL VENOUS SINUS STENOSIS BILATERAL': None, 'Cerebral Venous Thrombosis': None, 'VIRAL OR AUTOIMMUNE MENINGITIS': None, '1 DURAL SINUS THROMBOSIS; 2 DURAL AV FISTULA': None, 'LEFT THROMBOSIS OF CEREBRAL VENOUS SINUSES': None, 'Chiari Malformation Type 1 ': None, 'Possible reaction to prednisone/antibiotics for sinusitis': None, 'Traumatic Brain Injury, Chronic Thrombosis of Sagittal Sinus': None, 'OBSTRUCTION TYPE HYDROCEPHALUS, BLOCKED AT AQUED ...
# {nan: None, 2005.0: None, 2006.0: None, 2007.0: None, 2008.0: None, 2009.0: None, 2010.0: None, 2011.0: None, 2012.0: None, 2013.0: None, 2014.0: None}

# %%
#%pprinti
import pickle

with open('ihr_pickled.p', 'wb') as f:
    pickle.dump(ihr, f)

# %%
with open('ihr_pickled.p', 'rb') as f:
    newobj = pickle.load(f)

# %%
newobj.elements
# Out:
# ['race',
#  'sex',
#  'ethnic',
#  'education',
#  'employment',
#  'dx_date',
#  'diamox',
#  'lasix',
#  'topamax',
#  'neptazane',
#  'dxc_confirm',
#  'dxc_diagnosis',
#  'dxc_secondaryto',
#  'dxc_reviewdate']

# %% [markdown]
# # Cleaning the mappings (rrrgh, Mike)

# %%
#ihr.ethnic.mapdict.pop('Hispanic or Latino')
#ihr.ethnic.mapdict.pop('Non-Hispanic or Latino')
ihr.ethnic.mapdict
#ihr.ethnic.mapdict.pop('Hispanic or Latino')
#ihr.ethnic.mapdict.pop('Non-Hispanic or Latino')
ihr.race.mapdict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-0d6adcfff6f4> in <module>()
#       1 #ihr.ethnic.mapdict.pop('Hispanic or Latino')
#       2 #ihr.ethnic.mapdict.pop('Non-Hispanic or Latino')
# ----> 3 ihr.ethnic.mapdict
#       4 #ihr.ethnic.mapdict.pop('Hispanic or Latino')
#       5 #ihr.ethnic.mapdict.pop('Non-Hispanic or Latino')
#
# AttributeError: 'Registry' object has no attribute 'ethnic'

# %% [markdown]
# # Running Transform() Methods on each element

# %%
for x in ihr.race.postmap.dropna().index:
    count = 1
    exec("%s.etlobj.%s = Person(attr_person_source_value='%s')" % (ihr.regname, x, x))
    for col in ihr.race.postmap.columns:
        setattr(getattr(ihr.etlobj, x), 'attr_%s' % col, ihr.race.postmap.ix[x][col])
    count +=1

# %%
ihr.sex.transform()
ihr.race.transform()
ihr.ethnic.transform()
# Out:
# What is the target field?gender_concept_id
# Name of omop source (eg condition_source_value)?gender_source_value
# Mapped sex: type = , target_table = Not yet specified, target_field = gender_concept_id
# What is the target field?race_concept_id
# Name of omop source (eg condition_source_value)?race_source_value
# Mapped race: type = , target_table = Not yet specified, target_field = race_concept_id
# What is the target field?ethnicity_concept_id
# Name of omop source (eg condition_source_value)?ethnicity_source_value
# Mapped ethnic: type = , target_table = Not yet specified, target_field = ethnicity_concept_id
#                     gender_concept_id race_concept_id ethnicity_concept_id  \
# person_source_value
# ihr_1001                         8532            None         3.800356e+07
# ihr_1002                         8507            None         3.800356e+07
# ihr_1003                         8532            None         3.800356e+07
# ihr_1004                         8532            None         3.800356e+07
# GRDRLE238CPW                     8532            None         3.800356e+07
# ihr_1006                         8532            None         3.800356e+07
# ihr_1007                         8532            None         3.800356e+07
# ihr_1008                         8532            None         3.800356e+07
# ihr_1009                         8532            None         3.800356e+07
# ihr_1010                         8532            None         3.800356e+07
# GRDRTH223VY4                     8532            None         3.800356e+07
# ihr_1012                         8532            None         3.800356e+07
# ihr_1014                         8532            None         3.800356e+07
# ihr_1015                         8532            None         3.800356e+07
# ihr_1016                         8507            None         3.800356e+07
# ihr_1017                         8532            None         3.800356e+07
# ihr_1018                         8507            None         3.800356e+07
# ihr_1019                         8532            None         3.800356e+07
# ihr_1020                         8532            None         3.800356e+07
# ihr_1021                         8532            None         3.800356e+07
# ihr_1022                         8532            None         3.800356e+07
# ihr_1025                         8507            None         3.800356e+07
# ihr_1026                         8532            None         3.800356e+07
# ihr_1027                         8532            None         3.800356e+07
# ihr_1028                         8532            None         3.800356e+07
# ihr_1031                         8532            None         3.800356e+07
# ihr_1032                         8532            None         3.800356e+07
# ihr_1033                         8532            None         3.800356e+07
# ihr_1034                         8532            None         3.800356e+07
# ihr_1035                         8532            None         3.800356e+07
# ihr_1036                         8532            None         3.800356e+07
# ihr_1038                         8532            None         3.800356e+07
# ihr_1039                         8532            None         3.800356e+07
# ihr_1040                         8532            None         3.800356e+07
# GRDRFG106WW8                     8532            None         3.800356e+07
# ihr_1042                         8532            None                 None
# ihr_1043                         8532            None         3.800356e+07
# ihr_1047                         8532            None         3.800356e+07
# GRDRAL409ULW                     8532            None         3.800356e+07
# ihr_1053                         8532            None         3.800356e+07
# ihr_1056                         8532            None                 None
# ihr_1058                         8532            None         3.800356e+07
# ihr_1059                         8532            None         3.800356e+07
# ihr_1061                         8532            None         3.800356e+07
# ihr_1064                         8532            None         3.800356e+07
# ihr_1065                         8532            None         3.800356e+07
# ihr_1066                         8532            None         3.800356e+07
# ihr_1067                         8532            None         3.800356e+07
# ihr_2928             Non-Hispanic or Latino
# ihr_2929             Non-Hispanic or Latino
# GRDRXE210UAZ         Non-Hispanic or Latino
# ihr_2932                  Unknown/No answer
# GRDRBA530BA7         Non-Hispanic or Latino
# ihr_2935                  Unknown/No answer
# ihr_2936             Non-Hispanic or Latino
# ihr_2937                  Unknown/No answer
# ihr_2938             Non-Hispanic or Latino
# ihr_2942                  Unknown/No answer
# ihr_2943                  Unknown/No answer
# ihr_2946             Non-Hispanic or Latino
# ihr_2956             Non-Hispanic or Latino
# ihr_2962             Non-Hispanic or Latino
# ihr_2964             Non-Hispanic or Latino
# GRDRCR864XZ1         Non-Hispanic or Latino
# GRDRLJ977GXZ         Non-Hispanic or Latino
# GRDRFB330PND         Non-Hispanic or Latino
# GRDRKJ210LFT         Non-Hispanic or Latino
# GRDRXW886RWC         Non-Hispanic or Latino
# ihr_2997             Non-Hispanic or Latino
# GRDRLP163UBB         Non-Hispanic or Latino
# GRDRUV773JKD         Non-Hispanic or Latino
# GRDRCG029WR4         Non-Hispanic or Latino
# GRDRZV123ARC         Non-Hispanic or Latino
# GRDRDT961FAJ         Non-Hispanic or Latino
# GRDRBH559JUV         Non-Hispanic or Latino
# GRDRFV885YGW         Non-Hispanic or Latino
# GRDRHZ631AH8              Unknown/No answer
# GRDRZW150XCN         Non-Hispanic or Latino
# ihr_3027             Non-Hispanic or Latino
# GRDRYJ515VNB         Non-Hispanic or Latino
# GRDRAR156ED4         Non-Hispanic or Latino
# GRDRAY677HZD         Non-Hispanic or Latino
# GRDRHH641FBR         Non-Hispanic or Latino
# GRDRJL257JP9         Non-Hispanic or Latino
# GRDRGK274GGC         Non-Hispanic or Latino
# ihr_3044             Non-Hispanic or Latino
# GRDRTA910URN         Non-Hispanic or Latino
# GRDRFJ353PL9         Non-Hispanic or Latino
# ihr_3052             Non-Hispanic or Latino
# GRDRUB678ZVZ         Non-Hispanic or Latino
# GRDRTA546HHX         Non-Hispanic or Latino
# GRDRDU663KA7              Unknown/No answer
# ihr_3071             Non-Hispanic or Latino
# GRDRPL674JCA         Non-Hispanic or Latino
# GRDRVU794ZLE         Non-Hispanic or Latino
# GRDRYN587FVD         Non-Hispanic or Latino
# GRDRJT582WGP         Non-Hispanic or Latino
# GRDRLW552DH0         Non-Hispanic or Latino
# GRDRLA154MZY         Non-Hispanic or Latino
# GRDRRC814ERA         Non-Hispanic or Latino
# GRDRNU335GWH         Non-Hispanic or Latino
# GRDRPD128PUJ         Non-Hispanic or Latino

# %%
#ihr.sex.transform()
len(ihr.sex.postmap)
mult = ['ethnic', 'race']
for x in mult:
    getattr(ihr, x).transform()
# Out:
# What is the target field?ethnicity_concept_id
# Name of omop source (eg condition_source_value)?ethnicity_source_value
# Mapped ethnic: type = , target_table = Not yet specified, target_field = ethnicity_concept_id
# What is the target field?race_concept_id
# Name of omop source (eg condition_source_value)?race_source_value
# Mapped race: type = , target_table = Not yet specified, target_field = race_concept_id

# %% [markdown]
# ______
#
#
# # Creating the Staging Table
# 1. Create the source and target tables  with Pandas, setting indexes and drop to false so index column stays in the table as well.
# 2. Add to the staging table according to the pipeline
# - Note to self: **I need to create a pipeline dictionary**

# %%
person_staging = pd.read_sql_table('person', engine)
person_staging.set_index('person_source_value', inplace=True, drop=False)
source_table = pd.read_sql_table('ihr', engine)
source_table.set_index('person_source_value', inplace=True, drop=False)
source_table.tail()
# Out:
#                     person_source_value  Registry Unique Participant ID  \
# person_source_value
# GRDRLW552DH0               GRDRLW552DH0                            3095
# GRDRLA154MZY               GRDRLA154MZY                            3109
# GRDRRC814ERA               GRDRRC814ERA                            3124
# GRDRNU335GWH               GRDRNU335GWH                            3140
# GRDRPD128PUJ               GRDRPD128PUJ                            3145
#
#                     Atitle_x ASMversion_x  ASMdateDONE_x REGvitalStatus  \
# person_source_value
# GRDRLW552DH0         IHRPTHX       7/4/13           2013             No
# GRDRLA154MZY         IHRPTHX       7/4/13           2014             No
# GRDRRC814ERA         IHRPTHX       7/4/13           2014             No
# GRDRNU335GWH         IHRPTHX       7/4/13           2014             No
# GRDRPD128PUJ         IHRPTHX       7/5/13           2014             No
#
#                         sex  Year of Birth State of Residence  \
# person_source_value
# GRDRLW552DH0         Female           1970                 ON
# GRDRLA154MZY         Female           1976                 IN
# GRDRRC814ERA         Female           1977                 PA
# GRDRNU335GWH         Female           1969                 IL
# GRDRPD128PUJ           Male           1991                 NC
#
#                     Country of Residence State/Province of Birth   \
# person_source_value
# GRDRLW552DH0                          CA                       AB
# GRDRLA154MZY                          US                       IL
# GRDRRC814ERA                          US                       AR
# GRDRNU335GWH                          US                       IL
# GRDRPD128PUJ                          US                       NC
#
#                     Country of Birth     race                  ethnic  \
# person_source_value
# GRDRLW552DH0                      CA  1 White  Non-Hispanic or Latino
# GRDRLA154MZY                      US  1 White  Non-Hispanic or Latino
# GRDRRC814ERA                      US  1 White  Non-Hispanic or Latino
# GRDRNU335GWH                      US  1 White  Non-Hispanic or Latino
# GRDRPD128PUJ                      US  2 White  Non-Hispanic or Latino
#
#                       complete complete_else_relate complete_else_reason  \
# person_source_value
# GRDRLW552DH0         1 Patient                 None                 None
# GRDRLA154MZY         1 Patient                 None                 None
# GRDRRC814ERA         1 Patient                 None                 None
# GRDRNU335GWH         1 Patient                 None                 None
# GRDRPD128PUJ         2 Patient                 None                 None
#
#                                  education    employment           GUID  \
# person_source_value
# GRDRLW552DH0                       College  4 Unemployed   GRDRLW552DH0
# GRDRLA154MZY                       College   1 Full-Time   GRDRLA154MZY
# GRDRRC814ERA                   High School       6 Other   GRDRRC814ERA
# GRDRNU335GWH               Graduate School   1 Full-Time   GRDRNU335GWH
# GRDRPD128PUJ         Less than High School    5 Disabled   GRDRPD128PUJ
#
#                     diamox  lasix topamax neptazane surgwtloss  shunt  \
# person_source_value
# GRDRLW552DH0         1 Yes   None   1 Yes      None       2 No  1 Yes
# GRDRLA154MZY         1 Yes  1 Yes    None      None       2 No   2 No
# GRDRRC814ERA          None   None    None      None       2 No  1 Yes
# GRDRNU335GWH         1 Yes   None   1 Yes      None       2 No   2 No
# GRDRPD128PUJ         1 Yes   None    None      None       2 No  1 Yes
#
#                     shunt_num shunt_lp shunt_vp shunt_va subtemp cranialvault  \
# person_source_value
# GRDRLW552DH0                1     None    1 Yes     None    2 No         2 No
# GRDRLA154MZY             None     None     None     None    2 No         2 No
# GRDRRC814ERA                3     None    1 Yes     None    2 No   0 Not Sure
# GRDRNU335GWH             None     None     None     None    2 No         2 No
# GRDRPD128PUJ                2    1 Yes     None     None    2 No         2 No
#
#                      onsd onsd_side  \
# person_source_value
# GRDRLW552DH0         2 No      None
# GRDRLA154MZY         2 No      None
# GRDRRC814ERA         2 No      None
# GRDRNU335GWH         2 No      None
# GRDRPD128PUJ         2 No      None
#
#                                                                                                                      dxc_surgnotes  \
# person_source_value
# GRDRLW552DH0         Ventriculoperitoneal Shunt R (2012); revision; Stent (pt report) (2013); R Orbital Pseudotumor surgery (2009)
# GRDRLA154MZY                                                                                                                  None
# GRDRRC814ERA                                                                       Ventriculoperitoneal Shunt (2013) ; 3 revisions
# GRDRNU335GWH                                                                                                                  None
# GRDRPD128PUJ                                                                          Lumboperitoneal Shunt (2013); removed (2014)
#
#                      ht_curr  wt_curr  wt_dx  wt_oy_dx Atitle_y ASMversion_y  \
# person_source_value
# GRDRLW552DH0            63.0      255    300       250  IHRPTDX      7/10/14
# GRDRLA154MZY            65.0      240    245       240  IHRPTDX      7/10/14
# GRDRRC814ERA            65.5      174    200       236  IHRPTDX      7/10/14
# GRDRNU335GWH            65.0      214    223       229  IHRPTDX      7/27/12
# GRDRPD128PUJ            73.0      270    265       260  IHRPTDX      7/10/14
#
#                      ASMdateDONE_y dxc_ha dxc_tvo dxc_blurred dxc_tinn  \
# person_source_value
# GRDRLW552DH0                  2014  1 Yes   1 Yes       1 Yes    1 Yes
# GRDRLA154MZY                  2014  1 Yes    2 No       1 Yes    1 Yes
# GRDRRC814ERA                  2013  1 Yes   1 Yes       1 Yes    1 Yes
# GRDRNU335GWH                  2014  1 Yes   1 Yes       1 Yes    1 Yes
# GRDRPD128PUJ                  2014  1 Yes   1 Yes       1 Yes    1 Yes
#
#                     dxc_diplopia dxc_neck dxc_arthralgias dxc_ataxia  \
# person_source_value
# GRDRLW552DH0               1 Yes    1 Yes           1 Yes       2 No
# GRDRLA154MZY               1 Yes    1 Yes            2 No       2 No
# GRDRRC814ERA               1 Yes    1 Yes           1 Yes       2 No
# GRDRNU335GWH               1 Yes    1 Yes            2 No       2 No
# GRDRPD128PUJ                2 No    1 Yes           1 Yes       2 No
#
#                     dxc_facepalsy dxc_radicular dxc_pap dxc_pap_bilat  \
# person_source_value
# GRDRLW552DH0                 2 No          2 No   1 Yes         1 Yes
# GRDRLA154MZY                 2 No          2 No   1 Yes         1 Yes
# GRDRRC814ERA                 2 No          2 No    2 No          2 No
# GRDRNU335GWH                 2 No          2 No   1 Yes         1 Yes
# GRDRPD128PUJ                 2 No          2 No    2 No          2 No
#
#                     dxc_pap_unilat dxc_visualacuity dxc_perimetry  \
# person_source_value
# GRDRLW552DH0                  2 No             2 No         1 Yes
# GRDRLA154MZY                  2 No             2 No         1 Yes
# GRDRRC814ERA                  2 No             2 No         1 Yes
# GRDRNU335GWH                  2 No             2 No         1 Yes
# GRDRPD128PUJ                  2 No             2 No          2 No
#
#                     dxc_6thnerve dxc_emptysella dxc_flatglobe dxc_peridis  \
# person_source_value
# GRDRLW552DH0                2 No          1 Yes         1 Yes        2 No
# GRDRLA154MZY                2 No          1 Yes          2 No        2 No
# GRDRRC814ERA                2 No           2 No          2 No        2 No
# GRDRNU335GWH                   .              .             .           .
# GRDRPD128PUJ                2 No           2 No          2 No        2 No
#
#                     dxc_other                      dxc_otherspecify  \
# person_source_value
# GRDRLW552DH0            1 Yes  R relative afferent pupillary defect
# GRDRLA154MZY             2 No                                     .
# GRDRRC814ERA             2 No                                     .
# GRDRNU335GWH             2 No                                     .
# GRDRPD128PUJ             2 No                                     .
#
#                     dxc_neuroopthth dxc_lp1_op dxc_lp1_date  \
# person_source_value
# GRDRLW552DH0                  1 Yes        370         2012
# GRDRLA154MZY                  1 Yes        280         2013
# GRDRRC814ERA                      .        290         2013
# GRDRNU335GWH                      .        440            .
# GRDRPD128PUJ                  1 Yes        380         2013
#
#                                      dxc_lp1_position dxc_lp2_op  \
# person_source_value
# GRDRLW552DH0                                5 Unknown        275
# GRDRLA154MZY         1 Lateral Decubitus (lying side)          .
# GRDRRC814ERA         1 Lateral Decubitus (lying side)          .
# GRDRNU335GWH         1 Lateral Decubitus (lying side)          .
# GRDRPD128PUJ               2 Prone (lying on stomach)          .
#
#                      dxc_lp2_date dxc_lp2_position dxc_lp3_op dxc_lp3_date  \
# person_source_value
# GRDRLW552DH0                 2012                .          .            .
# GRDRLA154MZY                  NaN                .          .            .
# GRDRRC814ERA                  NaN                .          .            .
# GRDRNU335GWH                  NaN                .          .            .
# GRDRPD128PUJ                  NaN                .          .            .
#
#                     dxc_lp3_position dxc_lp4_op dxc_lp4_date dxc_lp4_position  \
# person_source_value
# GRDRLW552DH0                       .          .            .                .
# GRDRLA154MZY                       .          .            .                .
# GRDRRC814ERA                       .          .            .                .
# GRDRNU335GWH                       .          .            .                .
# GRDRPD128PUJ                       .          .            .                .
#
#                     dxc_diagnosis   dxc_confirm  \
# person_source_value
# GRDRLW552DH0            1 Primary  Confirmed IH
# GRDRLA154MZY            1 Primary  Confirmed IH
# GRDRRC814ERA            1 Primary  Confirmed IH
# GRDRNU335GWH            1 Primary  Confirmed IH
# GRDRPD128PUJ          2 Secondary  Confirmed IH
#
#                                                                   dxc_secondaryto  \
# person_source_value
# GRDRLW552DH0                                                                    .
# GRDRLA154MZY                                                                    .
# GRDRRC814ERA                                                                    .
# GRDRNU335GWH                                                                    .
# GRDRPD128PUJ         Traumatic Brain Injury, Chronic Thrombosis of Sagittal Sinus
#
#                      dxc_reviewdate  dx_date Imaging  Unnamed: 2 source_id_etl
# person_source_value
# GRDRLW552DH0                   2014     2012      No         NaN      ihr_3095
# GRDRLA154MZY                   2014     2012     Yes         NaN      ihr_3109
# GRDRRC814ERA                   2014     2013      No         NaN      ihr_3124
# GRDRNU335GWH                   2014     2013     Yes         NaN      ihr_3140
# GRDRPD128PUJ                   2014     2013     Yes         NaN      ihr_3145

# %%
person_staging[['year_of_birth', 'person_source_value', 'gender_source_value', 'race_source_value', 'ethnicity_source_value']] = source_table[['Year of Birth', 'person_source_value', 'sex', 'race', 'ethnic']]
#person_staging['person_source_value'] = source_table['person_source_value']
#person_staging['race_concept_id'] = source_table.apply(lambda x: ihr.race.mapdict[x])
person_staging['race_concept_id'] = ihr.race.postmap['race_concept_id']
person_staging.set_index('person_source_value', inplace=True)
#person_staging.pop('person_id')
person_staging['gender_concept_id'] = ihr.sex.postmap['gender_concept_id']
person_staging['gender_source_value'] = ihr.sex.postmap['gender_source_value']
person_staging['race_source_value'] = ihr.race.postmap['race_source_value']
person_staging['ethnicity_concept_id'] = ihr.ethnic.data.apply(lambda x: ihr.ethnic.mapdict[closest_match(x, ihr.ethnic.mapdict.keys())])
person_staging['ethnicity_source_value'] = ihr.ethnic.postmap['ethnicity_source_value']
person_staging['year_of_birth'] = source_table['Year of Birth']
person_staging['care_site_id'] = 1
#person_staging['gender_concept_id'] = ihr.sex.postmap['gender_concept_id']
#person_staging['ethnicity_concept_id'] = ihr.ethnic.data.apply(lambda x: ihr.ethnic.mapdict[closest_match(x, ihr.ethnic.mapdict.keys())])

# %%
df2 = person_staging.astype(object).where(pd.notnull(person_staging), None)
df2.to_sql('ihr_person_staging', engine, if_exists='replace')
#ihr.ethnic.postmap.tail()
#person_staging.to_sql('person', engine, if_exists='append', index=False)

# %%
person_staging
# Out:
#                      person_id  gender_concept_id  year_of_birth  \
# person_source_value
# ihr_1001                 47093               8532           1968
# ihr_1002                 47094               8507           1947
# ihr_1003                 47095               8532           1971
# ihr_1004                 47096               8532           1985
# GRDRLE238CPW             47097               8532           1979
# ihr_1006                 47098               8532           1971
# ihr_1007                 47099               8532           1963
# ihr_1008                 47100               8532           1977
# ihr_1009                 47101               8532           1975
# ihr_1010                 47102               8532           1958
# GRDRTH223VY4             47103               8532           1949
# ihr_1012                 47104               8532           1959
# ihr_1014                 47105               8532           1981
# ihr_1015                 47106               8532           1965
# ihr_1016                 47107               8507           1963
# ihr_1017                 47108               8532           1974
# ihr_1018                 47109               8507           1960
# ihr_1019                 47110               8532           1955
# ihr_1020                 47111               8532           1959
# ihr_1021                 47112               8532           1978
# ihr_1022                 47113               8532           1949
# ihr_1025                 47114               8507           1961
# ihr_1026                 47115               8532           1994
# ihr_1027                 47116               8532           1994
# ihr_1028                 47117               8532           1966
# ihr_1031                 47118               8532           1967
# ihr_1032                 47119               8532           1979
# ihr_1033                 47120               8532           1974
# ihr_1034                 47121               8532           1988
# ihr_1035                 47122               8532           1977
# ihr_1036                 47123               8532           1973
# ihr_1038                 47124               8532           1977
# ihr_1039                 47125               8532           1948
# ihr_1040                 47126               8532           1969
# GRDRFG106WW8             47127               8532           1966
# ihr_1042                 47128               8532           1964
# ihr_1043                 47129               8532           1963
# ihr_1047                 47130               8532           1968
# GRDRAL409ULW             47131               8532           1946
# GRDRZW150XCN                     4 More than one race  Non-Hispanic or Latino
# ihr_3027                                      1 White  Non-Hispanic or Latino
# GRDRYJ515VNB                                  1 White  Non-Hispanic or Latino
# GRDRAR156ED4                                  1 White  Non-Hispanic or Latino
# GRDRAY677HZD                                  1 White  Non-Hispanic or Latino
# GRDRHH641FBR                                  1 White  Non-Hispanic or Latino
# GRDRJL257JP9                                  1 White  Non-Hispanic or Latino
# GRDRGK274GGC                                  1 White  Non-Hispanic or Latino
# ihr_3044                                      1 White  Non-Hispanic or Latino
# GRDRTA910URN                                  1 White  Non-Hispanic or Latino
# GRDRFJ353PL9                                  1 White  Non-Hispanic or Latino
# ihr_3052                                      1 White  Non-Hispanic or Latino
# GRDRUB678ZVZ                                  1 White  Non-Hispanic or Latino
# GRDRTA546HHX                                  1 White  Non-Hispanic or Latino
# GRDRDU663KA7                 2 Black/African American       Unknown/No answer
# ihr_3071                                      1 White  Non-Hispanic or Latino
# GRDRPL674JCA                                  1 White  Non-Hispanic or Latino
# GRDRVU794ZLE                                  1 White  Non-Hispanic or Latino
# GRDRYN587FVD                                  1 White  Non-Hispanic or Latino
# GRDRJT582WGP                                  1 White  Non-Hispanic or Latino
# GRDRLW552DH0                                  1 White  Non-Hispanic or Latino
# GRDRLA154MZY                                  1 White  Non-Hispanic or Latino
# GRDRRC814ERA                                  1 White  Non-Hispanic or Latino
# GRDRNU335GWH                                  1 White  Non-Hispanic or Latino
# GRDRPD128PUJ                                  2 White  Non-Hispanic or Latino

# %%
session= Session()
naughty = []
for x in ihr.data.index:
    s = Person()
    s.attr_person_source_value = str(x)
    session.add(s)

# %%
session.commit()

# %%
x = 'attr_'
classlist = []
for y in Person.classes.keys():
    classlist.append(str(x + y))

# %%
classlist
# Out:
# ['attr_auth_user_user_permissions',
#  'attr_ethnicity',
#  'attr_procedure_cost',
#  'attr_avocado_dataquery',
#  'attr_visit_occurrence',
#  'attr_condition_concept',
#  'attr_auth_user',
#  'attr_avocado_datafield',
#  'attr_concept_relationship',
#  'attr_drug_condition',
#  'attr_drug_strength',
#  'attr_drug_type',
#  'attr_auth_permission',
#  'attr_avocado_datafield_sites',
#  'attr_avocado_dataview',
#  'attr_observation_condition',
#  'attr_procedure_type',
#  'attr_organization',
#  'attr_drug_cost',
#  'attr_care_site',
#  'attr_vocabulary',
#  'attr_avocado_log',
#  'attr_observation',
#  'attr_payer_plan_period',
#  'attr_procedure_concept',
#  'attr_south_migrationhistory',
#  'attr_avocado_datacategory',
#  'attr_django_site',
#  'attr_provider',
#  'attr_cohort',
#  'attr_drug_era',
#  'attr_death',
#  'attr_serrano_apitoken',
#  'attr_relationship',
#  'attr_person',
#  'attr_source_to_concept_map',
#  'attr_django_content_type',
#  'attr_observation_type',
#  'attr_condition_era',
#  'attr_django_admin_log',
#  'attr_auth_group_permissions',
#  'attr_avocado_dataconcept_sites',
#  'attr_concept_synonym',
#  'attr_condition_occurrence',
#  'attr_avocado_dataquery_shared_users',
#  'attr_condition_type',
#  'attr_drug_approval',
#  'attr_avocado_dataconceptfield',
#  'attr_concept_ancestor',
#  'attr_avocado_revision',
#  'attr_avocado_datacontext',
#  'attr_observation_value',
#  'attr_observation_concept',
#  'attr_location',
#  'attr_auth_user_groups',
#  'attr_avocado_dataconcept',
#  'attr_concept',
#  'attr_observation_period',
#  'attr_django_session',
#  'attr_drug_exposure',
#  'attr_race',
#  'attr_auth_group',
#  'attr_drug_concept',
#  'attr_procedure_occurrence']

# %%
ihr.race.postmap.loc['ihr_1593']['race_concept_id'] !='null'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-2c1e75589380> in <module>()
# ----> 1 ihr.race.postmap.loc['ihr_1593']['race_concept_id'] !='null'
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/core/series.py in __getitem__(self, key)
#     506     def __getitem__(self, key):
#     507         try:
# --> 508             result = self.index.get_value(self, key)
#     509
#     510             if not np.isscalar(result):
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/core/index.py in get_value(self, series, key)
#    1427                     raise InvalidIndexError(key)
#    1428                 else:
# -> 1429                     raise e1
#    1430             except Exception:  # pragma: no cover
#    1431                 raise e1
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/core/index.py in get_value(self, series, key)
#    1413
#    1414         try:
# -> 1415             return self._engine.get_value(s, k)
#    1416         except KeyError as e1:
#    1417             if len(self) > 0 and self.inferred_type in ['integer','boolean']:
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:3097)()
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2826)()
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3692)()
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12299)()
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12250)()
#
# KeyError: 'race_concept_id'

# %%
session = Session()
for x in ihr.data.index:
    s = Person()
    if ihr.race.postmap.loc[x]['race_concept_id'] != 'null':
        s.attr_race_concept_id = ihr.race.postmap.loc[x]['race_concept_id']
        s.attr_race_source_value = ihr.race.postmap.loc[x]['race_source_value']
    else: pass
    session.merge(s)
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ihr_1218
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ihr_1264
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ihr_1545
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ihr_1657
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ihr_1693
# ihr_1694
# ok
# ok
# ihr_1697
# ihr_1698
# ok
# ihr_1700
# ihr_1701
# ihr_1702
# ihr_1704
# ihr_1705
# ihr_1707
# ihr_1708
# ihr_1709
# GRDRLF320FMN
# ihr_1712
# ihr_1715
# ihr_1717
# ihr_1718
# ihr_1719
# ok
# ihr_1724
# GRDRRR844GJ6
# ihr_1726
# ihr_1727
# ok
# ihr_1730
# ihr_1731
# ihr_1732
# ihr_1733
# ihr_1734
# ihr_1735
# GRDRDH531MJJ
# ihr_1738
# ihr_1739
# ihr_1740
# ihr_1741
# GRDRZR928MAY
# ihr_1743
# ihr_1744
# ihr_2742
# ihr_2753
# ihr_2756
# ihr_2762
# ihr_2774
# GRDRHN100WFB
# ihr_2805
# ihr_2809
# GRDRTU735UEM
# ihr_2817
# ihr_2824
# ihr_2834
# ihr_2836
# ihr_2837
# ihr_2840
# ihr_2851
# ihr_2855
# GRDRNF170DFZ
# ihr_2866
# ihr_2877
# ihr_2881
# ihr_2884
# ihr_2889
# GRDRLZ632RB4
# ihr_2893
# GRDRHJ586ZD1
# GRDRHY646TD3
# ihr_2909
# ihr_2914
# ihr_2915
# ihr_2916
# ihr_2917
# ihr_2918
# ihr_2919
# ihr_2922
# ihr_2925
# ihr_2926
# ihr_2927
# ihr_2928
# ihr_2929
# GRDRXE210UAZ
# ok
# GRDRBA530BA7
# ihr_2935
# ihr_2936
# ok
# ihr_2938
# ok
# ihr_2943
# ihr_2946
# ihr_2956
# ihr_2962
# ihr_2964
# GRDRCR864XZ1
# GRDRLJ977GXZ
# GRDRFB330PND
# GRDRKJ210LFT
# GRDRXW886RWC
# ihr_2997
# GRDRLP163UBB
# GRDRUV773JKD
# GRDRCG029WR4
# GRDRZV123ARC
# GRDRDT961FAJ
# GRDRBH559JUV
# GRDRFV885YGW
# GRDRHZ631AH8
# GRDRZW150XCN
# ihr_3027
# GRDRYJ515VNB
# GRDRAR156ED4
# GRDRAY677HZD
# GRDRHH641FBR
# GRDRJL257JP9
# GRDRGK274GGC
# ihr_3044
# GRDRTA910URN
# GRDRFJ353PL9
# ihr_3052
# GRDRUB678ZVZ
# GRDRTA546HHX
# GRDRDU663KA7
# ihr_3071
# GRDRPL674JCA
# GRDRVU794ZLE
# GRDRYN587FVD
# GRDRJT582WGP
# GRDRLW552DH0
# GRDRLA154MZY
# GRDRRC814ERA
# GRDRNU335GWH
# ok

# %%
stmt = lambda x: db.execute("update person set %s = '%s' where person_source_value = '%s'" % (x['col'], x['val'], x['idx']))
stmt({'col': 'race_concept_id', 'val': 8527, 'idx':'ihr_1001'})
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyError                           Traceback (most recent call last)
# <ipython-input-570-6891d55ef831> in <module>()
#       1 stmt = lambda x: db.execute("update person set %s = '%s' where person_source_value = '%s'" % (x['col'], x['val'], x['idx']))
# ----> 2 stmt({'col': 'race_concept_id', 'val': 8527, 'idx':'ihr_1001'})
#
# <ipython-input-570-6891d55ef831> in <lambda>(x)
# ----> 1 stmt = lambda x: db.execute("update person set %s = '%s' where person_source_value = '%s'" % (x['col'], x['val'], x['idx']))
#       2 stmt({'col': 'race_concept_id', 'val': 8527, 'idx':'ihr_1001'})
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/postgresql/driver/pq3.py in execute(self, query)
#    2304 		)
#    2305                 self._pq_push(q, self)
# -> 2306                 self._pq_complete()
#    2307
#    2308 	def do(self, language : str, source : str,
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/postgresql/driver/pq3.py in _pq_complete(self)
#    2602                         # Raise an error *iff* one occurred.
#    2603                         if x.fatal is not None:
# -> 2604                                 self.typio.raise_error(x.error_message, cause = getattr(x, 'exception', None))
#    2605                         del self._controller
#    2606
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/postgresql/driver/pq3.py in raise_error(self, error_message, ClientError, **kw)
#     539                         self.raise_client_error(error_message, **kw)
#     540                 else:
# --> 541                         self.raise_server_error(error_message, **kw)
#     542
#     543         ##
#
# /Users/vassr/anaconda/envs/py3/lib/python3.3/site-packages/postgresql/driver/pq3.py in raise_server_error(self, error_message, cause, creator)
#     530                         raise server_error from cause
#     531                 else:
# --> 532                         raise server_error
#     533
#     534         def raise_error(self, error_message, ClientError = element.ClientError, **kw):
#
# ForeignKeyError: insert or update on table "person" violates foreign key constraint "race_concept_id_refs_concept_id_6d5d9e46"
#   CODE: 23503
#   LOCATION: File 'ri_triggers.c', line 3232, in ri_ReportViolation from SERVER
#   DETAIL: Key (race_concept_id)=(8527) is not present in table "race".
# CONNECTION: [idle]
#   client_address: ::1/128
#   client_port: 62507
#   version:
#     PostgreSQL 9.3.5 on x86_64-apple-darwin13.3.0, compiled by Apple LLVM version 5.0 (clang-500.2.79) (based on LLVM 3.3svn), 64-bit
# CONNECTOR: [Host] pq://vassr:***@localhost:5432/vassr
#   category: None
# DRIVER: postgresql.driver.pq3.Driver

# %%
mapping.mapmaster[0][closest_match('yes', mapping.mapkeys)]

# %%
namhrload = etl.IO('mhr', 'namhr/current_data/20141029MHRegsitry.xlsx')
mhrdata = namhrload.xls_to_df()



mhr = etl.Registry('mhr', mhrdata)

mhr.mapmaster = open_mapping_sheet('namhr')

with open('namhr/current_data/csv/20141029MHRegsitry.csv', 'r') as f:
    wha = f.readlines()

mapmaster = mapping.to_dict(orient="records")


auto = AutoMapper(ihr)
auto.automap(ihr.dxc_secondaryto.elementname)




pd.read_sql_query("select * from person;", engine)
# Out:
# Regsitry instance mhr created, but could not add it to database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-a51492577cda> in <module>()
#       6 mhr = etl.Registry('mhr', mhrdata)
#       7
# ----> 8 mhr.mapmaster = open_mapping_sheet('namhr')
#       9
#      10 with open('namhr/current_data/csv/20141029MHRegsitry.csv', 'r') as f:
#
# NameError: name 'open_mapping_sheet' is not defined

# %%
ihr.mapmaster = mapping.to_dict(orient="records")

ihr.race.transform()

# %%
            
   # def update(self):
    #    cols = list(self.registry.postmap.columns)
     #   comma = ","
      #  for x in self.registry.postmap.index:
       #     row = self.registry.postmap.ix[x]
        #    rowdict = row.to_dict()
         #   for col in cols:
          #      setter = "set %s = %s" % (col, rowdict[col])
           #     db.execute("update public.person %s where public.%s like '%s';" % (setter, 'person_source_value', str(x)))

# %%
loader = DBLoader(db, ihr.race, 'person')


update = db.prepare("update %s set %s = (select $1::varchar) where person_source_value::text like $2::text;" % (self.target_table, self.target_field))


loader.update_all()

db.bind('postgres', user='', password='', host='', database='')

# %%
from pony.orm import *
db = Database()
db.bind('postgres', user='vassr', password='bluedog', host='localhost', database='vassr')

# %%
Base = declarative_base(metadata=MetaData(bind=engine))

class MyTable(Base):
    __table__ = sa.Table('person', Base.metadata, autoload=True)
    
ry =  MyTable()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-9857419aba07> in <module>()
#       7 ry =  MyTable()
#       8
# ----> 9 sa.reflect
#
# AttributeError: 'module' object has no attribute 'reflect'

# %%
tablename = 'person'
fieldname = 'race_source_value'
x = 123
typer = db.prepare("select data_type from information_schema.columns  where table_name = '%s' and column_name = '%s'" % (tablename, fieldname))
v1 = typer()[0][0]
ins = db.prepare("update %s set %s = (select %s::%s) where person_source_value::text like $1::text;" % (tablename, fieldname,x, v1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0097821a274f> in <module>()
#       2 fieldname = 'race_source_value'
#       3 x = 123
# ----> 4 typer = db.prepare("select data_type from information_schema.columns  where table_name = '%s' and column_name = '%s'" % (tablename, fieldname))
#       5 v1 = typer()[0][0]
#       6 ins = db.prepare("update %s set %s = (select %s::%s) where person_source_value::text like $1::text;" % (tablename, fieldname,x, v1))
#
# NameError: name 'db' is not defined

# %%
typedict = {'character':'',
'time with time zone':'',
'date':'',
'timestamp with time zone':'',
'smallint':'',
'character varying':'',
'boolean':'',
'double precision':'',
'integer':'',
'numeric':'',
'text':'',
'bigint':''}

# %%
dd = pd.DataFrame(ihr.dx_date.data * ihr.dx_date.data.apply(is_year)).apply(pd.to_datetime, infer_datetime_format=True, format='%Y')
ihr.dx_date.data = ihr.dx_date.data.apply(pd.to_datetime, infer_datetime_format=True, format='%Y')

# %%
for x in ihr.dx_date.data.iteritems():
    if not is_year(x):
        print(x)
# Out:
# (0, Timestamp('2002-01-01 00:00:00'))
# (1, Timestamp('2001-01-01 00:00:00'))
# (2, Timestamp('1997-01-01 00:00:00'))
# (3, Timestamp('2001-01-01 00:00:00'))
# (4, Timestamp('2001-01-01 00:00:00'))
# (5, Timestamp('2002-01-01 00:00:00'))
# (6, Timestamp('2002-01-01 00:00:00'))
# (7, Timestamp('2003-01-01 00:00:00'))
# (8, Timestamp('1995-01-01 00:00:00'))
# (9, Timestamp('2000-01-01 00:00:00'))
# (10, Timestamp('2001-01-01 00:00:00'))
# (11, Timestamp('2002-01-01 00:00:00'))
# (12, Timestamp('1999-01-01 00:00:00'))
# (13, Timestamp('2002-01-01 00:00:00'))
# (14, Timestamp('2002-01-01 00:00:00'))
# (15, Timestamp('2001-01-01 00:00:00'))
# (16, Timestamp('2003-01-01 00:00:00'))
# (17, Timestamp('1996-01-01 00:00:00'))
# (18, Timestamp('2002-01-01 00:00:00'))
# (19, Timestamp('2002-01-01 00:00:00'))
# (20, Timestamp('1998-01-01 00:00:00'))
# (21, Timestamp('1994-01-01 00:00:00'))
# (22, Timestamp('2001-01-01 00:00:00'))
# (23, Timestamp('2000-01-01 00:00:00'))
# (24, Timestamp('2002-01-01 00:00:00'))
# (25, Timestamp('2001-01-01 00:00:00'))
# (26, Timestamp('2001-01-01 00:00:00'))
# (27, Timestamp('2001-01-01 00:00:00'))
# (28, Timestamp('1999-01-01 00:00:00'))
# (29, Timestamp('1993-01-01 00:00:00'))
# (30, Timestamp('2000-01-01 00:00:00'))
# (31, Timestamp('2001-01-01 00:00:00'))
# (32, Timestamp('1999-01-01 00:00:00'))
# (33, Timestamp('2003-01-01 00:00:00'))
# (34, Timestamp('1999-01-01 00:00:00'))
# (35, Timestamp('2003-01-01 00:00:00'))
# (36, Timestamp('2002-01-01 00:00:00'))
# (37, Timestamp('1999-01-01 00:00:00'))
# (38, Timestamp('2002-01-01 00:00:00'))
# (39, Timestamp('2001-01-01 00:00:00'))
# (40, Timestamp('2003-01-01 00:00:00'))
# (41, Timestamp('2002-01-01 00:00:00'))
# (42, Timestamp('2002-01-01 00:00:00'))
# (43, Timestamp('2000-01-01 00:00:00'))
# (44, Timestamp('1996-01-01 00:00:00'))
# (45, Timestamp('1998-01-01 00:00:00'))
# (46, Timestamp('2001-01-01 00:00:00'))
# (47, Timestamp('1997-01-01 00:00:00'))
# (48, Timestamp('1987-01-01 00:00:00'))
# (49, Timestamp('2000-01-01 00:00:00'))
# (50, Timestamp('1992-01-01 00:00:00'))
# (51, Timestamp('2001-01-01 00:00:00'))
# (52, Timestamp('2003-01-01 00:00:00'))
# (53, Timestamp('1998-01-01 00:00:00'))
# (54, Timestamp('2001-01-01 00:00:00'))
# (55, Timestamp('1996-01-01 00:00:00'))
# (56, Timestamp('2001-01-01 00:00:00'))
# (57, Timestamp('1990-01-01 00:00:00'))
# (58, Timestamp('2001-01-01 00:00:00'))
# (59, Timestamp('2003-01-01 00:00:00'))
# (60, Timestamp('2000-01-01 00:00:00'))
# (61, Timestamp('2003-01-01 00:00:00'))
# (62, Timestamp('2003-01-01 00:00:00'))
# (63, Timestamp('1991-01-01 00:00:00'))
# (64, Timestamp('2003-01-01 00:00:00'))
# (65, Timestamp('1992-01-01 00:00:00'))
# (66, Timestamp('2002-01-01 00:00:00'))
# (67, Timestamp('2003-01-01 00:00:00'))
# (68, Timestamp('2002-01-01 00:00:00'))
# (69, Timestamp('1997-01-01 00:00:00'))
# (70, Timestamp('1999-01-01 00:00:00'))
# (71, Timestamp('2003-01-01 00:00:00'))
# (72, Timestamp('2003-01-01 00:00:00'))
# (73, Timestamp('2003-01-01 00:00:00'))
# (74, Timestamp('2003-01-01 00:00:00'))
# (75, Timestamp('1999-01-01 00:00:00'))
# (76, Timestamp('1989-01-01 00:00:00'))
# (77, Timestamp('1998-01-01 00:00:00'))
# (78, Timestamp('1998-01-01 00:00:00'))
# (79, Timestamp('2000-01-01 00:00:00'))
# (80, Timestamp('1996-01-01 00:00:00'))
# (81, Timestamp('2003-01-01 00:00:00'))
# (82, Timestamp('1991-01-01 00:00:00'))
# (83, Timestamp('1991-01-01 00:00:00'))
# (84, Timestamp('2003-01-01 00:00:00'))
# (85, Timestamp('1998-01-01 00:00:00'))
# (86, Timestamp('1970-01-01 00:00:00.000000300'))
# (87, Timestamp('2002-01-01 00:00:00'))
# (88, Timestamp('1998-01-01 00:00:00'))
# (89, Timestamp('2003-01-01 00:00:00'))
# (90, Timestamp('2002-01-01 00:00:00'))
# (91, Timestamp('2003-01-01 00:00:00'))
# (92, Timestamp('1970-01-01 00:00:00.000000300'))
# (93, Timestamp('1991-01-01 00:00:00'))
# (94, Timestamp('2003-01-01 00:00:00'))
# (95, Timestamp('2003-01-01 00:00:00'))
# (96, Timestamp('1992-01-01 00:00:00'))
# (97, Timestamp('2002-01-01 00:00:00'))
# (98, Timestamp('2000-01-01 00:00:00'))
# (99, Timestamp('1996-01-01 00:00:00'))
# (100, Timestamp('2002-01-01 00:00:00'))
# (101, Timestamp('2002-01-01 00:00:00'))
# (102, Timestamp('2002-01-01 00:00:00'))
# (103, Timestamp('2003-01-01 00:00:00'))
# (104, Timestamp('2003-01-01 00:00:00'))
# (105, Timestamp('2003-01-01 00:00:00'))
# (106, Timestamp('1999-01-01 00:00:00'))
# (107, Timestamp('2000-01-01 00:00:00'))
# (108, Timestamp('1986-01-01 00:00:00'))
# (109, Timestamp('2003-01-01 00:00:00'))
# (110, Timestamp('2000-01-01 00:00:00'))
# (111, Timestamp('2003-01-01 00:00:00'))
# (112, Timestamp('2004-01-01 00:00:00'))
# (113, Timestamp('1997-01-01 00:00:00'))
# (114, Timestamp('1999-01-01 00:00:00'))
# (115, Timestamp('2004-01-01 00:00:00'))
# (116, Timestamp('1985-01-01 00:00:00'))
# (117, Timestamp('2002-01-01 00:00:00'))
# (118, Timestamp('1970-01-01 00:00:00.000000300'))
# (119, Timestamp('2003-01-01 00:00:00'))
# (120, Timestamp('2000-01-01 00:00:00'))
# (121, Timestamp('1999-01-01 00:00:00'))
# (122, Timestamp('1998-01-01 00:00:00'))
# (123, Timestamp('2003-01-01 00:00:00'))
# (124, Timestamp('2000-01-01 00:00:00'))
# (125, Timestamp('2001-01-01 00:00:00'))
# (126, Timestamp('1997-01-01 00:00:00'))
# (127, Timestamp('2001-01-01 00:00:00'))
# (128, Timestamp('2002-01-01 00:00:00'))
# (129, Timestamp('2003-01-01 00:00:00'))
# (130, Timestamp('2002-01-01 00:00:00'))
# (131, Timestamp('2004-01-01 00:00:00'))
# (132, Timestamp('2000-01-01 00:00:00'))
# (133, Timestamp('2001-01-01 00:00:00'))
# (134, Timestamp('2004-01-01 00:00:00'))
# (135, Timestamp('2004-01-01 00:00:00'))
# (136, Timestamp('2003-01-01 00:00:00'))
# (137, Timestamp('1993-01-01 00:00:00'))
# (138, Timestamp('2004-01-01 00:00:00'))
# (139, Timestamp('2002-01-01 00:00:00'))
# (140, Timestamp('2002-01-01 00:00:00'))
# (141, Timestamp('2003-01-01 00:00:00'))
# (142, Timestamp('2000-01-01 00:00:00'))
# (143, Timestamp('1986-01-01 00:00:00'))
# (144, Timestamp('2002-01-01 00:00:00'))
# (145, Timestamp('1987-01-01 00:00:00'))
# (146, Timestamp('2001-01-01 00:00:00'))
# (147, Timestamp('1970-01-01 00:00:00.000000300'))
# (148, Timestamp('2003-01-01 00:00:00'))
# (149, Timestamp('2003-01-01 00:00:00'))
# (150, Timestamp('1996-01-01 00:00:00'))
# (151, Timestamp('1993-01-01 00:00:00'))
# (152, Timestamp('1976-01-01 00:00:00'))
# (153, Timestamp('2003-01-01 00:00:00'))
# (154, Timestamp('1996-01-01 00:00:00'))
# (155, Timestamp('2003-01-01 00:00:00'))
# (156, Timestamp('2003-01-01 00:00:00'))
# (157, Timestamp('1996-01-01 00:00:00'))
# (158, Timestamp('1985-01-01 00:00:00'))
# (159, Timestamp('1992-01-01 00:00:00'))
# (160, Timestamp('1995-01-01 00:00:00'))
# (161, Timestamp('2001-01-01 00:00:00'))
# (162, Timestamp('2004-01-01 00:00:00'))
# (163, Timestamp('2003-01-01 00:00:00'))
# (164, Timestamp('2000-01-01 00:00:00'))
# (165, Timestamp('1999-01-01 00:00:00'))
# (166, Timestamp('1998-01-01 00:00:00'))
# (167, Timestamp('1993-01-01 00:00:00'))
# (168, Timestamp('2001-01-01 00:00:00'))
# (169, Timestamp('1999-01-01 00:00:00'))
# (170, Timestamp('2004-01-01 00:00:00'))
# (171, Timestamp('1998-01-01 00:00:00'))
# (172, Timestamp('1996-01-01 00:00:00'))
# (173, Timestamp('2001-01-01 00:00:00'))
# (174, Timestamp('2004-01-01 00:00:00'))
# (175, Timestamp('2003-01-01 00:00:00'))
# (176, Timestamp('1970-01-01 00:00:00.000000300'))
# (177, Timestamp('2004-01-01 00:00:00'))
# (178, Timestamp('2003-01-01 00:00:00'))
# (179, Timestamp('2004-01-01 00:00:00'))
# (180, Timestamp('2002-01-01 00:00:00'))
# (181, Timestamp('1991-01-01 00:00:00'))
# (182, Timestamp('1993-01-01 00:00:00'))
# (183, Timestamp('2002-01-01 00:00:00'))
# (184, Timestamp('1985-01-01 00:00:00'))
# (185, Timestamp('1999-01-01 00:00:00'))
# (186, Timestamp('1982-01-01 00:00:00'))
# (187, Timestamp('1994-01-01 00:00:00'))
# (188, Timestamp('1991-01-01 00:00:00'))
# (189, Timestamp('2000-01-01 00:00:00'))
# (190, Timestamp('2004-01-01 00:00:00'))
# (191, Timestamp('2004-01-01 00:00:00'))
# (192, Timestamp('2004-01-01 00:00:00'))
# (193, Timestamp('2002-01-01 00:00:00'))
# (194, Timestamp('2000-01-01 00:00:00'))
# (195, Timestamp('1970-01-01 00:00:00.000000300'))
# (196, Timestamp('2001-01-01 00:00:00'))
# (197, Timestamp('2004-01-01 00:00:00'))
# (198, Timestamp('2004-01-01 00:00:00'))
# (199, Timestamp('2001-01-01 00:00:00'))
# (200, Timestamp('1995-01-01 00:00:00'))
# (201, Timestamp('1983-01-01 00:00:00'))
# (202, Timestamp('2004-01-01 00:00:00'))
# (203, Timestamp('2000-01-01 00:00:00'))
# (204, Timestamp('2000-01-01 00:00:00'))
# (205, Timestamp('1996-01-01 00:00:00'))
# (206, Timestamp('2004-01-01 00:00:00'))
# (207, Timestamp('2002-01-01 00:00:00'))
# (208, Timestamp('1992-01-01 00:00:00'))
# (209, Timestamp('2004-01-01 00:00:00'))
# (210, Timestamp('1992-01-01 00:00:00'))
# (211, Timestamp('1994-01-01 00:00:00'))
# (212, Timestamp('1996-01-01 00:00:00'))
# (213, Timestamp('1993-01-01 00:00:00'))
# (214, Timestamp('1970-01-01 00:00:00.000000300'))
# (215, Timestamp('1996-01-01 00:00:00'))
# (216, Timestamp('2001-01-01 00:00:00'))
# (217, Timestamp('2003-01-01 00:00:00'))
# (218, Timestamp('1996-01-01 00:00:00'))
# (219, Timestamp('2004-01-01 00:00:00'))
# (220, Timestamp('2001-01-01 00:00:00'))
# (221, Timestamp('2003-01-01 00:00:00'))
# (222, Timestamp('2004-01-01 00:00:00'))
# (223, Timestamp('2000-01-01 00:00:00'))
# (224, Timestamp('2001-01-01 00:00:00'))
# (225, Timestamp('2004-01-01 00:00:00'))
# (226, Timestamp('2000-01-01 00:00:00'))
# (227, Timestamp('2002-01-01 00:00:00'))
# (228, Timestamp('2001-01-01 00:00:00'))
# (229, Timestamp('2003-01-01 00:00:00'))
# (230, Timestamp('2004-01-01 00:00:00'))
# (231, Timestamp('1997-01-01 00:00:00'))
# (232, Timestamp('2003-01-01 00:00:00'))
# (233, Timestamp('2004-01-01 00:00:00'))
# (234, Timestamp('1997-01-01 00:00:00'))
# (235, Timestamp('2003-01-01 00:00:00'))
# (236, Timestamp('2002-01-01 00:00:00'))
# (237, Timestamp('2003-01-01 00:00:00'))
# (238, Timestamp('1981-01-01 00:00:00'))
# (239, Timestamp('2004-01-01 00:00:00'))
# (240, Timestamp('1993-01-01 00:00:00'))
# (241, Timestamp('2004-01-01 00:00:00'))
# (242, Timestamp('1997-01-01 00:00:00'))
# (243, Timestamp('2004-01-01 00:00:00'))
# (244, Timestamp('2003-01-01 00:00:00'))
# (245, Timestamp('2003-01-01 00:00:00'))
# (246, Timestamp('1985-01-01 00:00:00'))
# (247, Timestamp('1998-01-01 00:00:00'))
# (248, Timestamp('1992-01-01 00:00:00'))
# (249, Timestamp('1988-01-01 00:00:00'))
# (250, Timestamp('2004-01-01 00:00:00'))
# (251, Timestamp('1974-01-01 00:00:00'))
# (252, Timestamp('1999-01-01 00:00:00'))
# (253, Timestamp('2003-01-01 00:00:00'))
# (254, Timestamp('2002-01-01 00:00:00'))
# (255, Timestamp('2004-01-01 00:00:00'))
# (256, Timestamp('2004-01-01 00:00:00'))
# (257, Timestamp('2005-01-01 00:00:00'))
# (258, Timestamp('2001-01-01 00:00:00'))
# (259, Timestamp('2002-01-01 00:00:00'))
# (260, Timestamp('2003-01-01 00:00:00'))
# (261, Timestamp('2003-01-01 00:00:00'))
# (262, Timestamp('2004-01-01 00:00:00'))
# (263, Timestamp('2003-01-01 00:00:00'))
# (264, Timestamp('2002-01-01 00:00:00'))
# (265, Timestamp('2004-01-01 00:00:00'))
# (266, Timestamp('1983-01-01 00:00:00'))
# (267, Timestamp('2004-01-01 00:00:00'))
# (268, Timestamp('2005-01-01 00:00:00'))
# (269, Timestamp('2004-01-01 00:00:00'))
# (270, Timestamp('2004-01-01 00:00:00'))
# (271, Timestamp('2003-01-01 00:00:00'))
# (272, Timestamp('2004-01-01 00:00:00'))
# (273, Timestamp('2003-01-01 00:00:00'))
# (274, Timestamp('2001-01-01 00:00:00'))
# (275, Timestamp('2002-01-01 00:00:00'))
# (276, Timestamp('1984-01-01 00:00:00'))
# (277, Timestamp('2004-01-01 00:00:00'))
# (278, Timestamp('1997-01-01 00:00:00'))
# (279, Timestamp('2000-01-01 00:00:00'))
# (280, Timestamp('1987-01-01 00:00:00'))
# (281, Timestamp('2003-01-01 00:00:00'))
# (282, Timestamp('2004-01-01 00:00:00'))
# (283, Timestamp('2005-01-01 00:00:00'))
# (284, Timestamp('2004-01-01 00:00:00'))
# (285, Timestamp('2005-01-01 00:00:00'))
# (286, Timestamp('2005-01-01 00:00:00'))
# (287, Timestamp('1970-01-01 00:00:00.000000300'))
# (288, Timestamp('2002-01-01 00:00:00'))
# (289, Timestamp('1999-01-01 00:00:00'))
# (290, Timestamp('2001-01-01 00:00:00'))
# (291, Timestamp('2005-01-01 00:00:00'))
# (292, Timestamp('2005-01-01 00:00:00'))
# (293, Timestamp('2005-01-01 00:00:00'))
# (294, Timestamp('2004-01-01 00:00:00'))
# (295, Timestamp('2003-01-01 00:00:00'))
# (296, Timestamp('2004-01-01 00:00:00'))
# (297, Timestamp('2004-01-01 00:00:00'))
# (298, Timestamp('2005-01-01 00:00:00'))
# (299, Timestamp('1989-01-01 00:00:00'))
# (300, Timestamp('2004-01-01 00:00:00'))
# (301, Timestamp('2003-01-01 00:00:00'))
# (302, Timestamp('1999-01-01 00:00:00'))
# (303, Timestamp('1996-01-01 00:00:00'))
# (304, Timestamp('2005-01-01 00:00:00'))
# (305, Timestamp('2004-01-01 00:00:00'))
# (306, Timestamp('2005-01-01 00:00:00'))
# (307, Timestamp('2005-01-01 00:00:00'))
# (308, Timestamp('1995-01-01 00:00:00'))
# (309, Timestamp('1997-01-01 00:00:00'))
# (310, Timestamp('2004-01-01 00:00:00'))
# (311, Timestamp('2001-01-01 00:00:00'))
# (312, Timestamp('1987-01-01 00:00:00'))
# (313, Timestamp('2004-01-01 00:00:00'))
# (314, Timestamp('2004-01-01 00:00:00'))
# (315, Timestamp('2000-01-01 00:00:00'))
# (316, Timestamp('1998-01-01 00:00:00'))
# (317, Timestamp('1998-01-01 00:00:00'))
# (318, Timestamp('2005-01-01 00:00:00'))
# (319, Timestamp('1980-01-01 00:00:00'))
# (320, Timestamp('2004-01-01 00:00:00'))
# (321, Timestamp('1992-01-01 00:00:00'))
# (322, Timestamp('2004-01-01 00:00:00'))
# (323, Timestamp('2005-01-01 00:00:00'))
# (324, Timestamp('2004-01-01 00:00:00'))
# (325, Timestamp('2004-01-01 00:00:00'))
# (326, Timestamp('1995-01-01 00:00:00'))
# (327, Timestamp('2002-01-01 00:00:00'))
# (328, Timestamp('2002-01-01 00:00:00'))
# (329, Timestamp('1998-01-01 00:00:00'))
# (330, Timestamp('1984-01-01 00:00:00'))
# (331, Timestamp('2004-01-01 00:00:00'))
# (332, Timestamp('1995-01-01 00:00:00'))
# (333, Timestamp('2003-01-01 00:00:00'))
# (334, Timestamp('1993-01-01 00:00:00'))
# (335, Timestamp('2005-01-01 00:00:00'))
# (336, Timestamp('2001-01-01 00:00:00'))
# (337, Timestamp('1998-01-01 00:00:00'))
# (338, Timestamp('1990-01-01 00:00:00'))
# (339, Timestamp('2002-01-01 00:00:00'))
# (340, Timestamp('2005-01-01 00:00:00'))
# (341, Timestamp('2004-01-01 00:00:00'))
# (342, Timestamp('2004-01-01 00:00:00'))
# (343, Timestamp('2003-01-01 00:00:00'))
# (344, Timestamp('1998-01-01 00:00:00'))
# (345, Timestamp('2005-01-01 00:00:00'))
# (346, Timestamp('2005-01-01 00:00:00'))
# (347, Timestamp('2000-01-01 00:00:00'))
# (348, Timestamp('2000-01-01 00:00:00'))
# (349, Timestamp('2005-01-01 00:00:00'))
# (350, Timestamp('2005-01-01 00:00:00'))
# (351, Timestamp('1995-01-01 00:00:00'))
# (352, Timestamp('2004-01-01 00:00:00'))
# (353, Timestamp('1969-01-01 00:00:00'))
# (354, Timestamp('2004-01-01 00:00:00'))
# (355, Timestamp('2005-01-01 00:00:00'))
# (356, Timestamp('2005-01-01 00:00:00'))
# (357, Timestamp('1993-01-01 00:00:00'))
# (358, Timestamp('1988-01-01 00:00:00'))
# (359, Timestamp('2005-01-01 00:00:00'))
# (360, Timestamp('2002-01-01 00:00:00'))
# (361, Timestamp('2004-01-01 00:00:00'))
# (362, Timestamp('2005-01-01 00:00:00'))
# (363, Timestamp('2004-01-01 00:00:00'))
# (364, Timestamp('2005-01-01 00:00:00'))
# (365, Timestamp('1993-01-01 00:00:00'))
# (366, Timestamp('2003-01-01 00:00:00'))
# (367, Timestamp('2005-01-01 00:00:00'))
# (368, Timestamp('2004-01-01 00:00:00'))
# (369, Timestamp('1996-01-01 00:00:00'))
# (370, Timestamp('2001-01-01 00:00:00'))
# (371, Timestamp('2000-01-01 00:00:00'))
# (372, Timestamp('1998-01-01 00:00:00'))
# (373, Timestamp('1986-01-01 00:00:00'))
# (374, Timestamp('2004-01-01 00:00:00'))
# (375, Timestamp('2004-01-01 00:00:00'))
# (376, Timestamp('1997-01-01 00:00:00'))
# (377, Timestamp('1999-01-01 00:00:00'))
# (378, Timestamp('2005-01-01 00:00:00'))
# (379, Timestamp('1998-01-01 00:00:00'))
# (380, Timestamp('2001-01-01 00:00:00'))
# (381, Timestamp('2005-01-01 00:00:00'))
# (382, Timestamp('1970-01-01 00:00:00.000000300'))
# (383, Timestamp('2001-01-01 00:00:00'))
# (384, Timestamp('2002-01-01 00:00:00'))
# (385, Timestamp('2005-01-01 00:00:00'))
# (386, Timestamp('1999-01-01 00:00:00'))
# (387, Timestamp('2001-01-01 00:00:00'))
# (388, Timestamp('1998-01-01 00:00:00'))
# (389, Timestamp('2005-01-01 00:00:00'))
# (390, Timestamp('2005-01-01 00:00:00'))
# (391, Timestamp('2005-01-01 00:00:00'))
# (392, Timestamp('2005-01-01 00:00:00'))
# (393, Timestamp('2005-01-01 00:00:00'))
# (394, Timestamp('2005-01-01 00:00:00'))
# (395, Timestamp('2004-01-01 00:00:00'))
# (396, Timestamp('2005-01-01 00:00:00'))
# (397, Timestamp('2005-01-01 00:00:00'))
# (398, Timestamp('2004-01-01 00:00:00'))
# (399, Timestamp('2005-01-01 00:00:00'))
# (400, Timestamp('2005-01-01 00:00:00'))
# (401, Timestamp('2005-01-01 00:00:00'))
# (402, Timestamp('1970-01-01 00:00:00.000000300'))
# (403, Timestamp('2004-01-01 00:00:00'))
# (404, Timestamp('2001-01-01 00:00:00'))
# (405, Timestamp('1995-01-01 00:00:00'))
# (406, Timestamp('2003-01-01 00:00:00'))
# (407, Timestamp('1998-01-01 00:00:00'))
# (408, Timestamp('1991-01-01 00:00:00'))
# (409, Timestamp('1996-01-01 00:00:00'))
# (410, Timestamp('2003-01-01 00:00:00'))
# (411, Timestamp('1992-01-01 00:00:00'))
# (412, Timestamp('2001-01-01 00:00:00'))
# (413, Timestamp('1993-01-01 00:00:00'))
# (414, Timestamp('2006-01-01 00:00:00'))
# (415, Timestamp('2006-01-01 00:00:00'))
# (416, Timestamp('2005-01-01 00:00:00'))
# (417, Timestamp('2005-01-01 00:00:00'))
# (418, Timestamp('2005-01-01 00:00:00'))
# (419, Timestamp('1992-01-01 00:00:00'))
# (420, Timestamp('2005-01-01 00:00:00'))
# (421, Timestamp('2005-01-01 00:00:00'))
# (422, Timestamp('2006-01-01 00:00:00'))
# (423, Timestamp('2006-01-01 00:00:00'))
# (424, Timestamp('2004-01-01 00:00:00'))
# (425, Timestamp('2005-01-01 00:00:00'))
# (426, Timestamp('2006-01-01 00:00:00'))
# (427, Timestamp('2005-01-01 00:00:00'))
# (428, Timestamp('2004-01-01 00:00:00'))
# (429, Timestamp('2006-01-01 00:00:00'))
# (430, Timestamp('2005-01-01 00:00:00'))
# (431, Timestamp('2006-01-01 00:00:00'))
# (432, Timestamp('2002-01-01 00:00:00'))
# (433, Timestamp('2003-01-01 00:00:00'))
# (434, Timestamp('1999-01-01 00:00:00'))
# (435, Timestamp('2002-01-01 00:00:00'))
# (436, Timestamp('2006-01-01 00:00:00'))
# (437, Timestamp('2002-01-01 00:00:00'))
# (438, Timestamp('2006-01-01 00:00:00'))
# (439, Timestamp('2001-01-01 00:00:00'))
# (440, Timestamp('1988-01-01 00:00:00'))
# (441, Timestamp('2006-01-01 00:00:00'))
# (442, Timestamp('2001-01-01 00:00:00'))
# (443, Timestamp('2000-01-01 00:00:00'))
# (444, Timestamp('2006-01-01 00:00:00'))
# (445, Timestamp('1996-01-01 00:00:00'))
# (446, Timestamp('2003-01-01 00:00:00'))
# (447, Timestamp('2004-01-01 00:00:00'))
# (448, Timestamp('1999-01-01 00:00:00'))
# (449, Timestamp('2006-01-01 00:00:00'))
# (450, Timestamp('2000-01-01 00:00:00'))
# (451, Timestamp('2005-01-01 00:00:00'))
# (452, Timestamp('2000-01-01 00:00:00'))
# (453, Timestamp('1990-01-01 00:00:00'))
# (454, Timestamp('2006-01-01 00:00:00'))
# (455, Timestamp('2005-01-01 00:00:00'))
# (456, Timestamp('1988-01-01 00:00:00'))
# (457, Timestamp('1997-01-01 00:00:00'))
# (458, Timestamp('2006-01-01 00:00:00'))
# (459, Timestamp('2006-01-01 00:00:00'))
# (460, Timestamp('2000-01-01 00:00:00'))
# (461, Timestamp('2006-01-01 00:00:00'))
# (462, Timestamp('1970-01-01 00:00:00.000000300'))
# (463, Timestamp('2000-01-01 00:00:00'))
# (464, Timestamp('2005-01-01 00:00:00'))
# (465, Timestamp('2006-01-01 00:00:00'))
# (466, Timestamp('2006-01-01 00:00:00'))
# (467, Timestamp('1989-01-01 00:00:00'))
# (468, Timestamp('1992-01-01 00:00:00'))
# (469, Timestamp('1998-01-01 00:00:00'))
# (470, Timestamp('2004-01-01 00:00:00'))
# (471, Timestamp('2004-01-01 00:00:00'))
# (472, Timestamp('1984-01-01 00:00:00'))
# (473, Timestamp('2006-01-01 00:00:00'))
# (474, Timestamp('2004-01-01 00:00:00'))
# (475, Timestamp('2005-01-01 00:00:00'))
# (476, Timestamp('2005-01-01 00:00:00'))
# (477, Timestamp('2006-01-01 00:00:00'))
# (478, Timestamp('2006-01-01 00:00:00'))
# (479, Timestamp('1985-01-01 00:00:00'))
# (480, Timestamp('2000-01-01 00:00:00'))
# (481, Timestamp('2000-01-01 00:00:00'))
# (482, Timestamp('2005-01-01 00:00:00'))
# (483, Timestamp('1997-01-01 00:00:00'))
# (484, Timestamp('1990-01-01 00:00:00'))
# (485, Timestamp('2006-01-01 00:00:00'))
# (486, Timestamp('2006-01-01 00:00:00'))
# (487, Timestamp('2006-01-01 00:00:00'))
# (488, Timestamp('2006-01-01 00:00:00'))
# (489, Timestamp('2006-01-01 00:00:00'))
# (490, Timestamp('2001-01-01 00:00:00'))
# (491, Timestamp('1985-01-01 00:00:00'))
# (492, Timestamp('1970-01-01 00:00:00.000000300'))
# (493, Timestamp('2003-01-01 00:00:00'))
# (494, Timestamp('2005-01-01 00:00:00'))
# (495, Timestamp('2006-01-01 00:00:00'))
# (496, Timestamp('2006-01-01 00:00:00'))
# (497, Timestamp('2005-01-01 00:00:00'))
# (498, Timestamp('2006-01-01 00:00:00'))
# (499, Timestamp('2006-01-01 00:00:00'))
# (500, Timestamp('2003-01-01 00:00:00'))
# (501, Timestamp('2000-01-01 00:00:00'))
# (502, Timestamp('1984-01-01 00:00:00'))
# (503, Timestamp('2005-01-01 00:00:00'))
# (504, Timestamp('2004-01-01 00:00:00'))
# (505, Timestamp('2001-01-01 00:00:00'))
# (506, Timestamp('2006-01-01 00:00:00'))
# (507, Timestamp('2005-01-01 00:00:00'))
# (508, Timestamp('2001-01-01 00:00:00'))
# (509, Timestamp('2001-01-01 00:00:00'))
# (510, Timestamp('2001-01-01 00:00:00'))
# (511, Timestamp('2006-01-01 00:00:00'))
# (512, Timestamp('2006-01-01 00:00:00'))
# (513, Timestamp('1993-01-01 00:00:00'))
# (514, Timestamp('2006-01-01 00:00:00'))
# (515, Timestamp('1995-01-01 00:00:00'))
# (516, Timestamp('2006-01-01 00:00:00'))
# (517, Timestamp('1990-01-01 00:00:00'))
# (518, Timestamp('2006-01-01 00:00:00'))
# (519, Timestamp('2006-01-01 00:00:00'))
# (520, Timestamp('2006-01-01 00:00:00'))
# (521, Timestamp('2007-01-01 00:00:00'))
# (522, Timestamp('2007-01-01 00:00:00'))
# (523, Timestamp('1980-01-01 00:00:00'))
# (524, Timestamp('2006-01-01 00:00:00'))
# (525, Timestamp('2007-01-01 00:00:00'))
# (526, Timestamp('2004-01-01 00:00:00'))
# (527, Timestamp('2005-01-01 00:00:00'))
# (528, Timestamp('2002-01-01 00:00:00'))
# (529, Timestamp('2006-01-01 00:00:00'))
# (530, Timestamp('2006-01-01 00:00:00'))
# (531, Timestamp('2007-01-01 00:00:00'))
# (532, Timestamp('2007-01-01 00:00:00'))
# (533, Timestamp('2007-01-01 00:00:00'))
# (534, Timestamp('2004-01-01 00:00:00'))
# (535, Timestamp('2007-01-01 00:00:00'))
# (536, Timestamp('2006-01-01 00:00:00'))
# (537, Timestamp('2003-01-01 00:00:00'))
# (538, Timestamp('2004-01-01 00:00:00'))
# (539, Timestamp('2007-01-01 00:00:00'))
# (540, Timestamp('1992-01-01 00:00:00'))
# (541, Timestamp('2003-01-01 00:00:00'))
# (542, Timestamp('1987-01-01 00:00:00'))
# (543, Timestamp('1995-01-01 00:00:00'))
# (544, Timestamp('2007-01-01 00:00:00'))
# (545, Timestamp('1970-01-01 00:00:00.000000300'))
# (546, Timestamp('2007-01-01 00:00:00'))
# (547, Timestamp('2007-01-01 00:00:00'))
# (548, Timestamp('2000-01-01 00:00:00'))
# (549, Timestamp('2001-01-01 00:00:00'))
# (550, Timestamp('2002-01-01 00:00:00'))
# (551, Timestamp('2007-01-01 00:00:00'))
# (552, Timestamp('1999-01-01 00:00:00'))
# (553, Timestamp('2005-01-01 00:00:00'))
# (554, Timestamp('1997-01-01 00:00:00'))
# (555, Timestamp('2006-01-01 00:00:00'))
# (556, Timestamp('1978-01-01 00:00:00'))
# (557, Timestamp('2007-01-01 00:00:00'))
# (558, Timestamp('2007-01-01 00:00:00'))
# (559, Timestamp('2007-01-01 00:00:00'))
# (560, Timestamp('2007-01-01 00:00:00'))
# (561, Timestamp('2004-01-01 00:00:00'))
# (562, Timestamp('2007-01-01 00:00:00'))
# (563, Timestamp('2005-01-01 00:00:00'))
# (564, Timestamp('2007-01-01 00:00:00'))
# (565, Timestamp('2007-01-01 00:00:00'))
# (566, Timestamp('2007-01-01 00:00:00'))
# (567, Timestamp('2006-01-01 00:00:00'))
# (568, Timestamp('2007-01-01 00:00:00'))
# (569, Timestamp('1995-01-01 00:00:00'))
# (570, Timestamp('2005-01-01 00:00:00'))
# (571, Timestamp('2006-01-01 00:00:00'))
# (572, Timestamp('2005-01-01 00:00:00'))
# (573, Timestamp('2005-01-01 00:00:00'))
# (574, Timestamp('2007-01-01 00:00:00'))
# (575, Timestamp('2007-01-01 00:00:00'))
# (576, Timestamp('2006-01-01 00:00:00'))
# (577, Timestamp('2001-01-01 00:00:00'))
# (578, Timestamp('2001-01-01 00:00:00'))
# (579, Timestamp('2007-01-01 00:00:00'))
# (580, Timestamp('2007-01-01 00:00:00'))
# (581, Timestamp('2007-01-01 00:00:00'))
# (582, Timestamp('2007-01-01 00:00:00'))
# (583, Timestamp('2006-01-01 00:00:00'))
# (584, Timestamp('2006-01-01 00:00:00'))
# (585, Timestamp('2003-01-01 00:00:00'))
# (586, Timestamp('2007-01-01 00:00:00'))
# (587, Timestamp('1992-01-01 00:00:00'))
# (588, Timestamp('2007-01-01 00:00:00'))
# (589, Timestamp('2006-01-01 00:00:00'))
# (590, Timestamp('1999-01-01 00:00:00'))
# (591, Timestamp('2007-01-01 00:00:00'))
# (592, Timestamp('2006-01-01 00:00:00'))
# (593, Timestamp('2007-01-01 00:00:00'))
# (594, Timestamp('2007-01-01 00:00:00'))
# (595, Timestamp('2007-01-01 00:00:00'))
# (596, Timestamp('2005-01-01 00:00:00'))
# (597, Timestamp('1970-01-01 00:00:00.000000300'))
# (598, Timestamp('1998-01-01 00:00:00'))
# (599, Timestamp('2007-01-01 00:00:00'))
# (600, Timestamp('1997-01-01 00:00:00'))
# (601, Timestamp('2007-01-01 00:00:00'))
# (602, Timestamp('1974-01-01 00:00:00'))
# (603, Timestamp('2001-01-01 00:00:00'))
# (604, Timestamp('2007-01-01 00:00:00'))
# (605, Timestamp('1999-01-01 00:00:00'))
# (606, Timestamp('2006-01-01 00:00:00'))
# (607, Timestamp('2007-01-01 00:00:00'))
# (608, Timestamp('2007-01-01 00:00:00'))
# (609, Timestamp('2001-01-01 00:00:00'))
# (610, Timestamp('2007-01-01 00:00:00'))
# (611, Timestamp('2007-01-01 00:00:00'))
# (612, Timestamp('1991-01-01 00:00:00'))
# (613, Timestamp('2006-01-01 00:00:00'))
# (614, Timestamp('2007-01-01 00:00:00'))
# (615, Timestamp('2003-01-01 00:00:00'))
# (616, Timestamp('2007-01-01 00:00:00'))
# (617, Timestamp('2007-01-01 00:00:00'))
# (618, Timestamp('2007-01-01 00:00:00'))
# (619, Timestamp('1999-01-01 00:00:00'))
# (620, Timestamp('2002-01-01 00:00:00'))
# (621, Timestamp('2006-01-01 00:00:00'))
# (622, Timestamp('2005-01-01 00:00:00'))
# (623, Timestamp('2007-01-01 00:00:00'))
# (624, Timestamp('2007-01-01 00:00:00'))
# (625, Timestamp('2006-01-01 00:00:00'))
# (626, Timestamp('2007-01-01 00:00:00'))
# (627, Timestamp('2007-01-01 00:00:00'))
# (628, Timestamp('2003-01-01 00:00:00'))
# (629, Timestamp('2007-01-01 00:00:00'))
# (630, Timestamp('2007-01-01 00:00:00'))
# (631, Timestamp('2004-01-01 00:00:00'))
# (632, Timestamp('1985-01-01 00:00:00'))
# (633, Timestamp('2007-01-01 00:00:00'))
# (634, Timestamp('1997-01-01 00:00:00'))
# (635, Timestamp('2007-01-01 00:00:00'))
# (636, Timestamp('1994-01-01 00:00:00'))
# (637, Timestamp('2007-01-01 00:00:00'))
# (638, Timestamp('2007-01-01 00:00:00'))
# (639, Timestamp('2007-01-01 00:00:00'))
# (640, Timestamp('2007-01-01 00:00:00'))
# (641, Timestamp('2007-01-01 00:00:00'))
# (642, Timestamp('2006-01-01 00:00:00'))
# (643, Timestamp('2002-01-01 00:00:00'))
# (644, Timestamp('2007-01-01 00:00:00'))
# (645, Timestamp('1984-01-01 00:00:00'))
# (646, Timestamp('2007-01-01 00:00:00'))
# (647, Timestamp('2007-01-01 00:00:00'))
# (648, Timestamp('2004-01-01 00:00:00'))
# (649, Timestamp('2008-01-01 00:00:00'))
# (650, Timestamp('2007-01-01 00:00:00'))
# (651, Timestamp('2007-01-01 00:00:00'))
# (652, Timestamp('2007-01-01 00:00:00'))
# (653, Timestamp('2008-01-01 00:00:00'))
# (654, Timestamp('2008-01-01 00:00:00'))
# (655, Timestamp('2007-01-01 00:00:00'))
# (656, Timestamp('2008-01-01 00:00:00'))
# (657, Timestamp('1997-01-01 00:00:00'))
# (658, Timestamp('1984-01-01 00:00:00'))
# (659, Timestamp('2003-01-01 00:00:00'))
# (660, Timestamp('2007-01-01 00:00:00'))
# (661, Timestamp('2007-01-01 00:00:00'))
# (662, Timestamp('2008-01-01 00:00:00'))
# (663, Timestamp('2007-01-01 00:00:00'))
# (664, Timestamp('2007-01-01 00:00:00'))
# (665, Timestamp('2001-01-01 00:00:00'))
# (666, Timestamp('2003-01-01 00:00:00'))
# (667, Timestamp('2001-01-01 00:00:00'))
# (668, Timestamp('2007-01-01 00:00:00'))
# (669, Timestamp('2007-01-01 00:00:00'))
# (670, Timestamp('1970-01-01 00:00:00.000000300'))
# (671, Timestamp('2007-01-01 00:00:00'))
# (672, Timestamp('1980-01-01 00:00:00'))
# (673, Timestamp('2007-01-01 00:00:00'))
# (674, Timestamp('2008-01-01 00:00:00'))
# (675, Timestamp('2007-01-01 00:00:00'))
# (676, Timestamp('2007-01-01 00:00:00'))
# (677, Timestamp('1995-01-01 00:00:00'))
# (678, Timestamp('2007-01-01 00:00:00'))
# (679, Timestamp('2005-01-01 00:00:00'))
# (680, Timestamp('2007-01-01 00:00:00'))
# (681, Timestamp('2008-01-01 00:00:00'))
# (682, Timestamp('2000-01-01 00:00:00'))
# (683, Timestamp('2006-01-01 00:00:00'))
# (684, Timestamp('2007-01-01 00:00:00'))
# (685, Timestamp('2008-01-01 00:00:00'))
# (686, Timestamp('1970-01-01 00:00:00.000000300'))
# (687, Timestamp('2008-01-01 00:00:00'))
# (688, Timestamp('2008-01-01 00:00:00'))
# (689, Timestamp('2002-01-01 00:00:00'))
# (690, Timestamp('2004-01-01 00:00:00'))
# (691, Timestamp('2008-01-01 00:00:00'))
# (692, Timestamp('2008-01-01 00:00:00'))
# (693, Timestamp('2007-01-01 00:00:00'))
# (694, Timestamp('2007-01-01 00:00:00'))
# (695, Timestamp('2001-01-01 00:00:00'))
# (696, Timestamp('2008-01-01 00:00:00'))
# (697, Timestamp('2008-01-01 00:00:00'))
# (698, Timestamp('2003-01-01 00:00:00'))
# (699, Timestamp('2007-01-01 00:00:00'))
# (700, Timestamp('2005-01-01 00:00:00'))
# (701, Timestamp('2005-01-01 00:00:00'))
# (702, Timestamp('2005-01-01 00:00:00'))
# (703, Timestamp('2006-01-01 00:00:00'))
# (704, Timestamp('2007-01-01 00:00:00'))
# (705, Timestamp('1990-01-01 00:00:00'))
# (706, Timestamp('2000-01-01 00:00:00'))
# (707, Timestamp('1994-01-01 00:00:00'))
# (708, Timestamp('2006-01-01 00:00:00'))
# (709, Timestamp('2002-01-01 00:00:00'))
# (710, Timestamp('2005-01-01 00:00:00'))
# (711, Timestamp('2008-01-01 00:00:00'))
# (712, Timestamp('2008-01-01 00:00:00'))
# (713, Timestamp('1991-01-01 00:00:00'))
# (714, Timestamp('1999-01-01 00:00:00'))
# (715, Timestamp('2008-01-01 00:00:00'))
# (716, Timestamp('1996-01-01 00:00:00'))
# (717, Timestamp('2007-01-01 00:00:00'))
# (718, Timestamp('2008-01-01 00:00:00'))
# (719, Timestamp('2006-01-01 00:00:00'))
# (720, Timestamp('2007-01-01 00:00:00'))
# (721, Timestamp('2008-01-01 00:00:00'))
# (722, Timestamp('2004-01-01 00:00:00'))
# (723, Timestamp('2007-01-01 00:00:00'))
# (724, Timestamp('2002-01-01 00:00:00'))
# (725, Timestamp('2007-01-01 00:00:00'))
# (726, Timestamp('2008-01-01 00:00:00'))
# (727, Timestamp('2006-01-01 00:00:00'))
# (728, Timestamp('2007-01-01 00:00:00'))
# (729, Timestamp('1991-01-01 00:00:00'))
# (730, Timestamp('2008-01-01 00:00:00'))
# (731, Timestamp('2008-01-01 00:00:00'))
# (732, Timestamp('2008-01-01 00:00:00'))
# (733, Timestamp('2008-01-01 00:00:00'))
# (734, Timestamp('2008-01-01 00:00:00'))
# (735, Timestamp('2006-01-01 00:00:00'))
# (736, Timestamp('2007-01-01 00:00:00'))
# (737, Timestamp('2003-01-01 00:00:00'))
# (738, Timestamp('2008-01-01 00:00:00'))
# (739, Timestamp('2008-01-01 00:00:00'))
# (740, Timestamp('2007-01-01 00:00:00'))
# (741, Timestamp('2008-01-01 00:00:00'))
# (742, Timestamp('2007-01-01 00:00:00'))
# (743, Timestamp('2007-01-01 00:00:00'))
# (744, Timestamp('2002-01-01 00:00:00'))
# (745, Timestamp('2007-01-01 00:00:00'))
# (746, Timestamp('2006-01-01 00:00:00'))
# (747, Timestamp('2000-01-01 00:00:00'))
# (748, Timestamp('1991-01-01 00:00:00'))
# (749, Timestamp('2006-01-01 00:00:00'))
# (750, Timestamp('2008-01-01 00:00:00'))
# (751, Timestamp('2002-01-01 00:00:00'))
# (752, Timestamp('2008-01-01 00:00:00'))
# (753, Timestamp('1996-01-01 00:00:00'))
# (754, Timestamp('2008-01-01 00:00:00'))
# (755, Timestamp('2007-01-01 00:00:00'))
# (756, Timestamp('2006-01-01 00:00:00'))
# (757, Timestamp('2000-01-01 00:00:00'))
# (758, Timestamp('2007-01-01 00:00:00'))
# (759, Timestamp('2008-01-01 00:00:00'))
# (760, Timestamp('2001-01-01 00:00:00'))
# (761, Timestamp('2007-01-01 00:00:00'))
# (762, Timestamp('2002-01-01 00:00:00'))
# (763, Timestamp('2008-01-01 00:00:00'))
# (764, Timestamp('2007-01-01 00:00:00'))
# (765, Timestamp('2007-01-01 00:00:00'))
# (766, Timestamp('2004-01-01 00:00:00'))
# (767, Timestamp('2007-01-01 00:00:00'))
# (768, Timestamp('2006-01-01 00:00:00'))
# (769, Timestamp('2007-01-01 00:00:00'))
# (770, Timestamp('2008-01-01 00:00:00'))
# (771, Timestamp('2007-01-01 00:00:00'))
# (772, Timestamp('2008-01-01 00:00:00'))
# (773, Timestamp('1992-01-01 00:00:00'))
# (774, Timestamp('2003-01-01 00:00:00'))
# (775, Timestamp('2006-01-01 00:00:00'))
# (776, Timestamp('1992-01-01 00:00:00'))
# (777, Timestamp('2008-01-01 00:00:00'))
# (778, Timestamp('2007-01-01 00:00:00'))
# (779, Timestamp('2005-01-01 00:00:00'))
# (780, Timestamp('2005-01-01 00:00:00'))
# (781, Timestamp('1989-01-01 00:00:00'))
# (782, Timestamp('2007-01-01 00:00:00'))
# (783, Timestamp('2005-01-01 00:00:00'))
# (784, Timestamp('2008-01-01 00:00:00'))
# (785, Timestamp('2008-01-01 00:00:00'))
# (786, Timestamp('2008-01-01 00:00:00'))
# (787, Timestamp('2008-01-01 00:00:00'))
# (788, Timestamp('1991-01-01 00:00:00'))
# (789, Timestamp('2008-01-01 00:00:00'))
# (790, Timestamp('2007-01-01 00:00:00'))
# (791, Timestamp('2008-01-01 00:00:00'))
# (792, Timestamp('2004-01-01 00:00:00'))
# (793, Timestamp('2002-01-01 00:00:00'))
# (794, Timestamp('2007-01-01 00:00:00'))
# (795, Timestamp('2005-01-01 00:00:00'))
# (796, Timestamp('1987-01-01 00:00:00'))
# (797, Timestamp('2008-01-01 00:00:00'))
# (798, Timestamp('2002-01-01 00:00:00'))
# (799, Timestamp('2007-01-01 00:00:00'))
# (800, Timestamp('2007-01-01 00:00:00'))
# (801, Timestamp('2008-01-01 00:00:00'))
# (802, Timestamp('1970-01-01 00:00:00.000000300'))
# (803, Timestamp('1998-01-01 00:00:00'))
# (804, Timestamp('2006-01-01 00:00:00'))
# (805, Timestamp('2004-01-01 00:00:00'))
# (806, Timestamp('2007-01-01 00:00:00'))
# (807, Timestamp('2007-01-01 00:00:00'))
# (808, Timestamp('2008-01-01 00:00:00'))
# (809, Timestamp('2004-01-01 00:00:00'))
# (810, Timestamp('2007-01-01 00:00:00'))
# (811, Timestamp('2006-01-01 00:00:00'))
# (812, Timestamp('2008-01-01 00:00:00'))
# (813, Timestamp('2008-01-01 00:00:00'))
# (814, Timestamp('2008-01-01 00:00:00'))
# (815, Timestamp('2007-01-01 00:00:00'))
# (816, Timestamp('2007-01-01 00:00:00'))
# (817, Timestamp('1987-01-01 00:00:00'))
# (818, Timestamp('1990-01-01 00:00:00'))
# (819, Timestamp('2007-01-01 00:00:00'))
# (820, Timestamp('2007-01-01 00:00:00'))
# (821, Timestamp('1992-01-01 00:00:00'))
# (822, Timestamp('2000-01-01 00:00:00'))
# (823, Timestamp('2006-01-01 00:00:00'))
# (824, Timestamp('2008-01-01 00:00:00'))
# (825, Timestamp('2005-01-01 00:00:00'))
# (826, Timestamp('2008-01-01 00:00:00'))
# (827, Timestamp('2007-01-01 00:00:00'))
# (828, Timestamp('2002-01-01 00:00:00'))
# (829, Timestamp('2008-01-01 00:00:00'))
# (830, Timestamp('2008-01-01 00:00:00'))
# (831, Timestamp('2004-01-01 00:00:00'))
# (832, Timestamp('2004-01-01 00:00:00'))
# (833, Timestamp('2008-01-01 00:00:00'))
# (834, Timestamp('2000-01-01 00:00:00'))
# (835, Timestamp('2001-01-01 00:00:00'))
# (836, Timestamp('1997-01-01 00:00:00'))
# (837, Timestamp('2008-01-01 00:00:00'))
# (838, Timestamp('2008-01-01 00:00:00'))
# (839, Timestamp('2008-01-01 00:00:00'))
# (840, Timestamp('2008-01-01 00:00:00'))
# (841, Timestamp('2008-01-01 00:00:00'))
# (842, Timestamp('2008-01-01 00:00:00'))
# (843, Timestamp('2008-01-01 00:00:00'))
# (844, Timestamp('2007-01-01 00:00:00'))
# (845, Timestamp('2008-01-01 00:00:00'))
# (846, Timestamp('2001-01-01 00:00:00'))
# (847, Timestamp('2007-01-01 00:00:00'))
# (848, Timestamp('2005-01-01 00:00:00'))
# (849, Timestamp('2008-01-01 00:00:00'))
# (850, Timestamp('2008-01-01 00:00:00'))
# (851, Timestamp('2008-01-01 00:00:00'))
# (852, Timestamp('2002-01-01 00:00:00'))
# (853, Timestamp('2008-01-01 00:00:00'))
# (854, Timestamp('2008-01-01 00:00:00'))
# (855, Timestamp('2008-01-01 00:00:00'))
# (856, Timestamp('2008-01-01 00:00:00'))
# (857, Timestamp('2008-01-01 00:00:00'))
# (858, Timestamp('2008-01-01 00:00:00'))
# (859, Timestamp('2008-01-01 00:00:00'))
# (860, Timestamp('2008-01-01 00:00:00'))
# (861, Timestamp('1984-01-01 00:00:00'))
# (862, Timestamp('2008-01-01 00:00:00'))
# (863, Timestamp('2008-01-01 00:00:00'))
# (864, Timestamp('2005-01-01 00:00:00'))
# (865, Timestamp('2006-01-01 00:00:00'))
# (866, Timestamp('2008-01-01 00:00:00'))
# (867, Timestamp('1970-01-01 00:00:00.000000300'))
# (868, Timestamp('2005-01-01 00:00:00'))
# (869, Timestamp('2008-01-01 00:00:00'))
# (870, Timestamp('2008-01-01 00:00:00'))
# (871, Timestamp('2007-01-01 00:00:00'))
# (872, Timestamp('2008-01-01 00:00:00'))
# (873, Timestamp('1994-01-01 00:00:00'))
# (874, Timestamp('2009-01-01 00:00:00'))
# (875, Timestamp('2003-01-01 00:00:00'))
# (876, Timestamp('2001-01-01 00:00:00'))
# (877, Timestamp('2008-01-01 00:00:00'))
# (878, Timestamp('2009-01-01 00:00:00'))
# (879, Timestamp('1998-01-01 00:00:00'))
# (880, Timestamp('2008-01-01 00:00:00'))
# (881, Timestamp('2009-01-01 00:00:00'))
# (882, Timestamp('1994-01-01 00:00:00'))
# (883, Timestamp('2009-01-01 00:00:00'))
# (884, Timestamp('2009-01-01 00:00:00'))
# (885, Timestamp('2008-01-01 00:00:00'))
# (886, Timestamp('2008-01-01 00:00:00'))
# (887, Timestamp('2003-01-01 00:00:00'))
# (888, Timestamp('2008-01-01 00:00:00'))
# (889, Timestamp('2008-01-01 00:00:00'))
# (890, Timestamp('2008-01-01 00:00:00'))
# (891, Timestamp('2009-01-01 00:00:00'))
# (892, Timestamp('2007-01-01 00:00:00'))
# (893, Timestamp('2008-01-01 00:00:00'))
# (894, Timestamp('2005-01-01 00:00:00'))
# (895, Timestamp('2005-01-01 00:00:00'))
# (896, Timestamp('2003-01-01 00:00:00'))
# (897, Timestamp('2007-01-01 00:00:00'))
# (898, Timestamp('2006-01-01 00:00:00'))
# (899, Timestamp('2001-01-01 00:00:00'))
# (900, Timestamp('2007-01-01 00:00:00'))
# (901, Timestamp('2009-01-01 00:00:00'))
# (902, Timestamp('2005-01-01 00:00:00'))
# (903, Timestamp('2009-01-01 00:00:00'))
# (904, Timestamp('1987-01-01 00:00:00'))
# (905, Timestamp('2009-01-01 00:00:00'))
# (906, Timestamp('2009-01-01 00:00:00'))
# (907, Timestamp('1970-01-01 00:00:00.000000300'))
# (908, Timestamp('2009-01-01 00:00:00'))
# (909, Timestamp('2007-01-01 00:00:00'))
# (910, Timestamp('2003-01-01 00:00:00'))
# (911, Timestamp('2009-01-01 00:00:00'))
# (912, Timestamp('2005-01-01 00:00:00'))
# (913, Timestamp('2009-01-01 00:00:00'))
# (914, Timestamp('2004-01-01 00:00:00'))
# (915, Timestamp('2007-01-01 00:00:00'))
# (916, Timestamp('2008-01-01 00:00:00'))
# (917, Timestamp('2009-01-01 00:00:00'))
# (918, Timestamp('2009-01-01 00:00:00'))
# (919, Timestamp('2009-01-01 00:00:00'))
# (920, Timestamp('2007-01-01 00:00:00'))
# (921, Timestamp('2009-01-01 00:00:00'))
# (922, Timestamp('2006-01-01 00:00:00'))
# (923, Timestamp('2009-01-01 00:00:00'))
# (924, Timestamp('2009-01-01 00:00:00'))
# (925, Timestamp('2009-01-01 00:00:00'))
# (926, Timestamp('1994-01-01 00:00:00'))
# (927, Timestamp('2008-01-01 00:00:00'))
# (928, Timestamp('2009-01-01 00:00:00'))
# (929, Timestamp('2009-01-01 00:00:00'))
# (930, Timestamp('1997-01-01 00:00:00'))
# (931, Timestamp('2009-01-01 00:00:00'))
# (932, Timestamp('1994-01-01 00:00:00'))
# (933, Timestamp('1994-01-01 00:00:00'))
# (934, Timestamp('2009-01-01 00:00:00'))
# (935, Timestamp('2007-01-01 00:00:00'))
# (936, Timestamp('2004-01-01 00:00:00'))
# (937, Timestamp('2009-01-01 00:00:00'))
# (938, Timestamp('2009-01-01 00:00:00'))
# (939, Timestamp('2009-01-01 00:00:00'))
# (940, Timestamp('2009-01-01 00:00:00'))
# (941, Timestamp('2008-01-01 00:00:00'))
# (942, Timestamp('2003-01-01 00:00:00'))
# (943, Timestamp('2009-01-01 00:00:00'))
# (944, Timestamp('2008-01-01 00:00:00'))
# (945, Timestamp('2009-01-01 00:00:00'))
# (946, Timestamp('2008-01-01 00:00:00'))
# (947, Timestamp('2009-01-01 00:00:00'))
# (948, Timestamp('2009-01-01 00:00:00'))
# (949, Timestamp('2008-01-01 00:00:00'))
# (950, Timestamp('2006-01-01 00:00:00'))
# (951, Timestamp('2009-01-01 00:00:00'))
# (952, Timestamp('1970-01-01 00:00:00.000000300'))
# (953, Timestamp('2007-01-01 00:00:00'))
# (954, Timestamp('2009-01-01 00:00:00'))
# (955, Timestamp('1970-01-01 00:00:00.000000300'))
# (956, Timestamp('2009-01-01 00:00:00'))
# (957, Timestamp('2009-01-01 00:00:00'))
# (958, Timestamp('2007-01-01 00:00:00'))
# (959, Timestamp('2009-01-01 00:00:00'))
# (960, Timestamp('2007-01-01 00:00:00'))
# (961, Timestamp('2009-01-01 00:00:00'))
# (962, Timestamp('2009-01-01 00:00:00'))
# (963, Timestamp('2009-01-01 00:00:00'))
# (964, Timestamp('1998-01-01 00:00:00'))
# (965, Timestamp('2009-01-01 00:00:00'))
# (966, Timestamp('2008-01-01 00:00:00'))
# (967, Timestamp('2009-01-01 00:00:00'))
# (968, Timestamp('2009-01-01 00:00:00'))
# (969, Timestamp('1982-01-01 00:00:00'))
# (970, Timestamp('2009-01-01 00:00:00'))
# (971, Timestamp('2008-01-01 00:00:00'))
# (972, Timestamp('1992-01-01 00:00:00'))
# (973, Timestamp('2009-01-01 00:00:00'))
# (974, Timestamp('2006-01-01 00:00:00'))
# (975, Timestamp('2007-01-01 00:00:00'))
# (976, Timestamp('2009-01-01 00:00:00'))
# (977, Timestamp('2008-01-01 00:00:00'))
# (978, Timestamp('2008-01-01 00:00:00'))
# (979, Timestamp('2002-01-01 00:00:00'))
# (980, Timestamp('2008-01-01 00:00:00'))
# (981, Timestamp('2007-01-01 00:00:00'))
# (982, Timestamp('2003-01-01 00:00:00'))
# (983, Timestamp('2009-01-01 00:00:00'))
# (984, Timestamp('2005-01-01 00:00:00'))
# (985, Timestamp('2000-01-01 00:00:00'))
# (986, Timestamp('2009-01-01 00:00:00'))
# (987, Timestamp('2009-01-01 00:00:00'))
# (988, Timestamp('2007-01-01 00:00:00'))
# (989, Timestamp('1996-01-01 00:00:00'))
# (990, Timestamp('2007-01-01 00:00:00'))
# (991, Timestamp('2009-01-01 00:00:00'))
# (992, Timestamp('2008-01-01 00:00:00'))
# (993, Timestamp('2005-01-01 00:00:00'))
# (994, Timestamp('2008-01-01 00:00:00'))
# (995, Timestamp('2009-01-01 00:00:00'))
# (996, Timestamp('2006-01-01 00:00:00'))
# (997, Timestamp('2009-01-01 00:00:00'))
# (998, Timestamp('2009-01-01 00:00:00'))
# (999, Timestamp('2008-01-01 00:00:00'))
# (1000, Timestamp('2008-01-01 00:00:00'))
# (1001, Timestamp('1998-01-01 00:00:00'))
# (1002, Timestamp('2009-01-01 00:00:00'))
# (1003, Timestamp('2008-01-01 00:00:00'))
# (1004, Timestamp('2008-01-01 00:00:00'))
# (1005, Timestamp('2009-01-01 00:00:00'))
# (1006, Timestamp('2005-01-01 00:00:00'))
# (1007, Timestamp('2009-01-01 00:00:00'))
# (1008, Timestamp('1992-01-01 00:00:00'))
# (1009, Timestamp('2008-01-01 00:00:00'))
# (1010, Timestamp('2009-01-01 00:00:00'))
# (1011, Timestamp('1970-01-01 00:00:00.000000300'))
# (1012, Timestamp('2009-01-01 00:00:00'))
# (1013, Timestamp('2009-01-01 00:00:00'))
# (1014, Timestamp('2009-01-01 00:00:00'))
# (1015, Timestamp('2007-01-01 00:00:00'))
# (1016, Timestamp('2009-01-01 00:00:00'))
# (1017, Timestamp('2008-01-01 00:00:00'))
# (1018, Timestamp('2009-01-01 00:00:00'))
# (1019, Timestamp('2008-01-01 00:00:00'))
# (1020, Timestamp('2010-01-01 00:00:00'))
# (1021, Timestamp('2009-01-01 00:00:00'))
# (1022, Timestamp('2010-01-01 00:00:00'))
# (1023, Timestamp('2008-01-01 00:00:00'))
# (1024, Timestamp('2009-01-01 00:00:00'))
# (1025, Timestamp('2009-01-01 00:00:00'))
# (1026, Timestamp('1970-01-01 00:00:00.000000300'))
# (1027, Timestamp('2009-01-01 00:00:00'))
# (1028, Timestamp('2009-01-01 00:00:00'))
# (1029, Timestamp('2009-01-01 00:00:00'))
# (1030, Timestamp('2007-01-01 00:00:00'))
# (1031, Timestamp('2007-01-01 00:00:00'))
# (1032, Timestamp('1970-01-01 00:00:00.000000300'))
# (1033, Timestamp('2010-01-01 00:00:00'))
# (1034, Timestamp('2009-01-01 00:00:00'))
# (1035, Timestamp('2008-01-01 00:00:00'))
# (1036, Timestamp('2010-01-01 00:00:00'))
# (1037, Timestamp('1970-01-01 00:00:00.000000300'))
# (1038, Timestamp('2008-01-01 00:00:00'))
# (1039, Timestamp('2009-01-01 00:00:00'))
# (1040, Timestamp('2005-01-01 00:00:00'))
# (1041, Timestamp('2008-01-01 00:00:00'))
# (1042, Timestamp('2009-01-01 00:00:00'))
# (1043, Timestamp('2010-01-01 00:00:00'))
# (1044, Timestamp('2009-01-01 00:00:00'))
# (1045, Timestamp('2008-01-01 00:00:00'))
# (1046, Timestamp('2010-01-01 00:00:00'))
# (1047, Timestamp('2008-01-01 00:00:00'))
# (1048, Timestamp('2000-01-01 00:00:00'))
# (1049, Timestamp('2001-01-01 00:00:00'))
# (1050, Timestamp('2005-01-01 00:00:00'))
# (1051, Timestamp('2006-01-01 00:00:00'))
# (1052, Timestamp('2010-01-01 00:00:00'))
# (1053, Timestamp('1970-01-01 00:00:00.000000300'))
# (1054, Timestamp('2010-01-01 00:00:00'))
# (1055, Timestamp('2002-01-01 00:00:00'))
# (1056, Timestamp('2008-01-01 00:00:00'))
# (1057, Timestamp('2009-01-01 00:00:00'))
# (1058, Timestamp('2008-01-01 00:00:00'))
# (1059, Timestamp('2009-01-01 00:00:00'))
# (1060, Timestamp('2010-01-01 00:00:00'))
# (1061, Timestamp('2008-01-01 00:00:00'))
# (1062, Timestamp('2009-01-01 00:00:00'))
# (1063, Timestamp('2009-01-01 00:00:00'))
# (1064, Timestamp('2010-01-01 00:00:00'))
# (1065, Timestamp('2010-01-01 00:00:00'))
# (1066, Timestamp('2006-01-01 00:00:00'))
# (1067, Timestamp('2007-01-01 00:00:00'))
# (1068, Timestamp('1997-01-01 00:00:00'))
# (1069, Timestamp('2010-01-01 00:00:00'))
# (1070, Timestamp('2009-01-01 00:00:00'))
# (1071, Timestamp('2003-01-01 00:00:00'))
# (1072, Timestamp('2008-01-01 00:00:00'))
# (1073, Timestamp('2010-01-01 00:00:00'))
# (1074, Timestamp('2010-01-01 00:00:00'))
# (1075, Timestamp('2010-01-01 00:00:00'))
# (1076, Timestamp('2010-01-01 00:00:00'))
# (1077, Timestamp('2010-01-01 00:00:00'))
# (1078, Timestamp('2010-01-01 00:00:00'))
# (1079, Timestamp('2008-01-01 00:00:00'))
# (1080, Timestamp('2010-01-01 00:00:00'))
# (1081, Timestamp('2005-01-01 00:00:00'))
# (1082, Timestamp('2009-01-01 00:00:00'))
# (1083, Timestamp('2010-01-01 00:00:00'))
# (1084, Timestamp('2006-01-01 00:00:00'))
# (1085, Timestamp('2008-01-01 00:00:00'))
# (1086, Timestamp('2007-01-01 00:00:00'))
# (1087, Timestamp('2010-01-01 00:00:00'))
# (1088, Timestamp('2010-01-01 00:00:00'))
# (1089, Timestamp('2010-01-01 00:00:00'))
# (1090, Timestamp('1998-01-01 00:00:00'))
# (1091, Timestamp('2005-01-01 00:00:00'))
# (1092, Timestamp('2006-01-01 00:00:00'))
# (1093, Timestamp('2008-01-01 00:00:00'))
# (1094, Timestamp('2009-01-01 00:00:00'))
# (1095, Timestamp('2009-01-01 00:00:00'))
# (1096, Timestamp('2010-01-01 00:00:00'))
# (1097, Timestamp('1998-01-01 00:00:00'))
# (1098, Timestamp('2009-01-01 00:00:00'))
# (1099, Timestamp('2008-01-01 00:00:00'))
# (1100, Timestamp('2009-01-01 00:00:00'))
# (1101, Timestamp('2008-01-01 00:00:00'))
# (1102, Timestamp('2010-01-01 00:00:00'))
# (1103, Timestamp('1997-01-01 00:00:00'))
# (1104, Timestamp('2005-01-01 00:00:00'))
# (1105, Timestamp('2006-01-01 00:00:00'))
# (1106, Timestamp('2010-01-01 00:00:00'))
# (1107, Timestamp('2010-01-01 00:00:00'))
# (1108, Timestamp('2002-01-01 00:00:00'))
# (1109, Timestamp('2010-01-01 00:00:00'))
# (1110, Timestamp('2009-01-01 00:00:00'))
# (1111, Timestamp('2010-01-01 00:00:00'))
# (1112, Timestamp('2008-01-01 00:00:00'))
# (1113, Timestamp('2009-01-01 00:00:00'))
# (1114, Timestamp('2003-01-01 00:00:00'))
# (1115, Timestamp('2009-01-01 00:00:00'))
# (1116, Timestamp('2010-01-01 00:00:00'))
# (1117, Timestamp('2004-01-01 00:00:00'))
# (1118, Timestamp('2010-01-01 00:00:00'))
# (1119, Timestamp('2010-01-01 00:00:00'))
# (1120, Timestamp('2010-01-01 00:00:00'))
# (1121, Timestamp('2010-01-01 00:00:00'))
# (1122, Timestamp('1989-01-01 00:00:00'))
# (1123, Timestamp('2008-01-01 00:00:00'))
# (1124, Timestamp('2007-01-01 00:00:00'))
# (1125, Timestamp('2008-01-01 00:00:00'))
# (1126, Timestamp('2004-01-01 00:00:00'))
# (1127, Timestamp('2010-01-01 00:00:00'))
# (1128, Timestamp('1999-01-01 00:00:00'))
# (1129, Timestamp('2010-01-01 00:00:00'))
# (1130, Timestamp('2009-01-01 00:00:00'))
# (1131, Timestamp('2010-01-01 00:00:00'))
# (1132, Timestamp('2007-01-01 00:00:00'))
# (1133, Timestamp('2010-01-01 00:00:00'))
# (1134, Timestamp('2010-01-01 00:00:00'))
# (1135, Timestamp('2010-01-01 00:00:00'))
# (1136, Timestamp('2010-01-01 00:00:00'))
# (1137, Timestamp('2008-01-01 00:00:00'))
# (1138, Timestamp('2009-01-01 00:00:00'))
# (1139, Timestamp('2002-01-01 00:00:00'))
# (1140, Timestamp('2009-01-01 00:00:00'))
# (1141, Timestamp('2010-01-01 00:00:00'))
# (1142, Timestamp('2010-01-01 00:00:00'))
# (1143, Timestamp('2006-01-01 00:00:00'))
# (1144, Timestamp('2010-01-01 00:00:00'))
# (1145, Timestamp('2009-01-01 00:00:00'))
# (1146, Timestamp('2009-01-01 00:00:00'))
# (1147, Timestamp('2004-01-01 00:00:00'))
# (1148, Timestamp('2009-01-01 00:00:00'))
# (1149, Timestamp('2010-01-01 00:00:00'))
# (1150, Timestamp('2010-01-01 00:00:00'))
# (1151, Timestamp('2010-01-01 00:00:00'))
# (1152, Timestamp('2009-01-01 00:00:00'))
# (1153, Timestamp('2010-01-01 00:00:00'))
# (1154, Timestamp('2010-01-01 00:00:00'))
# (1155, Timestamp('1970-01-01 00:00:00.000000300'))
# (1156, Timestamp('2010-01-01 00:00:00'))
# (1157, Timestamp('2010-01-01 00:00:00'))
# (1158, Timestamp('2008-01-01 00:00:00'))
# (1159, Timestamp('2009-01-01 00:00:00'))
# (1160, Timestamp('2010-01-01 00:00:00'))
# (1161, Timestamp('2010-01-01 00:00:00'))
# (1162, Timestamp('2007-01-01 00:00:00'))
# (1163, Timestamp('1992-01-01 00:00:00'))
# (1164, Timestamp('2010-01-01 00:00:00'))
# (1165, Timestamp('2010-01-01 00:00:00'))
# (1166, Timestamp('2010-01-01 00:00:00'))
# (1167, Timestamp('2010-01-01 00:00:00'))
# (1168, Timestamp('2010-01-01 00:00:00'))
# (1169, Timestamp('2009-01-01 00:00:00'))
# (1170, Timestamp('2011-01-01 00:00:00'))
# (1171, Timestamp('2008-01-01 00:00:00'))
# (1172, Timestamp('2007-01-01 00:00:00'))
# (1173, Timestamp('2009-01-01 00:00:00'))
# (1174, Timestamp('2010-01-01 00:00:00'))
# (1175, Timestamp('2010-01-01 00:00:00'))
# (1176, Timestamp('2010-01-01 00:00:00'))
# (1177, Timestamp('2004-01-01 00:00:00'))
# (1178, Timestamp('2010-01-01 00:00:00'))
# (1179, Timestamp('2010-01-01 00:00:00'))
# (1180, Timestamp('2004-01-01 00:00:00'))
# (1181, Timestamp('2011-01-01 00:00:00'))
# (1182, Timestamp('2010-01-01 00:00:00'))
# (1183, Timestamp('2010-01-01 00:00:00'))
# (1184, Timestamp('2003-01-01 00:00:00'))
# (1185, Timestamp('2010-01-01 00:00:00'))
# (1186, Timestamp('2010-01-01 00:00:00'))
# (1187, Timestamp('2010-01-01 00:00:00'))
# (1188, Timestamp('2008-01-01 00:00:00'))
# (1189, Timestamp('2006-01-01 00:00:00'))
# (1190, Timestamp('2010-01-01 00:00:00'))
# (1191, Timestamp('2011-01-01 00:00:00'))
# (1192, Timestamp('2010-01-01 00:00:00'))
# (1193, Timestamp('2010-01-01 00:00:00'))
# (1194, Timestamp('2011-01-01 00:00:00'))
# (1195, Timestamp('2010-01-01 00:00:00'))
# (1196, Timestamp('2010-01-01 00:00:00'))
# (1197, Timestamp('1989-01-01 00:00:00'))
# (1198, Timestamp('2011-01-01 00:00:00'))
# (1199, Timestamp('2008-01-01 00:00:00'))
# (1200, Timestamp('2011-01-01 00:00:00'))
# (1201, Timestamp('2001-01-01 00:00:00'))
# (1202, Timestamp('2010-01-01 00:00:00'))
# (1203, Timestamp('2010-01-01 00:00:00'))
# (1204, Timestamp('2007-01-01 00:00:00'))
# (1205, Timestamp('2011-01-01 00:00:00'))
# (1206, Timestamp('2004-01-01 00:00:00'))
# (1207, Timestamp('2010-01-01 00:00:00'))
# (1208, Timestamp('2011-01-01 00:00:00'))
# (1209, Timestamp('2011-01-01 00:00:00'))
# (1210, Timestamp('2004-01-01 00:00:00'))
# (1211, Timestamp('2010-01-01 00:00:00'))
# (1212, Timestamp('2010-01-01 00:00:00'))
# (1213, Timestamp('2004-01-01 00:00:00'))
# (1214, Timestamp('2011-01-01 00:00:00'))
# (1215, Timestamp('2001-01-01 00:00:00'))
# (1216, Timestamp('2011-01-01 00:00:00'))
# (1217, Timestamp('2011-01-01 00:00:00'))
# (1218, Timestamp('2010-01-01 00:00:00'))
# (1219, Timestamp('2007-01-01 00:00:00'))
# (1220, Timestamp('2010-01-01 00:00:00'))
# (1221, Timestamp('2007-01-01 00:00:00'))
# (1222, Timestamp('2010-01-01 00:00:00'))
# (1223, Timestamp('2010-01-01 00:00:00'))
# (1224, Timestamp('2008-01-01 00:00:00'))
# (1225, Timestamp('2011-01-01 00:00:00'))
# (1226, Timestamp('2010-01-01 00:00:00'))
# (1227, Timestamp('2010-01-01 00:00:00'))
# (1228, Timestamp('2011-01-01 00:00:00'))
# (1229, Timestamp('2010-01-01 00:00:00'))
# (1230, Timestamp('2006-01-01 00:00:00'))
# (1231, Timestamp('2008-01-01 00:00:00'))
# (1232, Timestamp('2005-01-01 00:00:00'))
# (1233, Timestamp('2007-01-01 00:00:00'))
# (1234, Timestamp('2010-01-01 00:00:00'))
# (1235, Timestamp('2011-01-01 00:00:00'))
# (1236, Timestamp('2010-01-01 00:00:00'))
# (1237, Timestamp('2010-01-01 00:00:00'))
# (1238, Timestamp('2011-01-01 00:00:00'))
# (1239, Timestamp('2011-01-01 00:00:00'))
# (1240, Timestamp('2006-01-01 00:00:00'))
# (1241, Timestamp('2010-01-01 00:00:00'))
# (1242, Timestamp('2000-01-01 00:00:00'))
# (1243, Timestamp('2009-01-01 00:00:00'))
# (1244, Timestamp('2010-01-01 00:00:00'))
# (1245, Timestamp('2009-01-01 00:00:00'))
# (1246, Timestamp('2007-01-01 00:00:00'))
# (1247, Timestamp('2011-01-01 00:00:00'))
# (1248, Timestamp('2011-01-01 00:00:00'))
# (1249, Timestamp('2005-01-01 00:00:00'))
# (1250, Timestamp('2011-01-01 00:00:00'))
# (1251, Timestamp('2011-01-01 00:00:00'))
# (1252, Timestamp('2007-01-01 00:00:00'))
# (1253, Timestamp('2011-01-01 00:00:00'))
# (1254, Timestamp('2011-01-01 00:00:00'))
# (1255, Timestamp('2009-01-01 00:00:00'))
# (1256, Timestamp('2011-01-01 00:00:00'))
# (1257, Timestamp('2007-01-01 00:00:00'))
# (1258, Timestamp('2009-01-01 00:00:00'))
# (1259, Timestamp('2010-01-01 00:00:00'))
# (1260, Timestamp('2011-01-01 00:00:00'))
# (1261, Timestamp('2000-01-01 00:00:00'))
# (1262, Timestamp('2011-01-01 00:00:00'))
# (1263, Timestamp('2011-01-01 00:00:00'))
# (1264, Timestamp('2012-01-01 00:00:00'))
# (1265, Timestamp('1970-01-01 00:00:00.000000300'))
# (1266, Timestamp('2012-01-01 00:00:00'))
# (1267, Timestamp('2012-01-01 00:00:00'))
# (1268, Timestamp('2012-01-01 00:00:00'))
# (1269, Timestamp('2012-01-01 00:00:00'))
# (1270, Timestamp('2010-01-01 00:00:00'))
# (1271, Timestamp('2011-01-01 00:00:00'))
# (1272, Timestamp('2011-01-01 00:00:00'))
# (1273, Timestamp('1992-01-01 00:00:00'))
# (1274, Timestamp('2012-01-01 00:00:00'))
# (1275, Timestamp('2010-01-01 00:00:00'))
# (1276, Timestamp('2011-01-01 00:00:00'))
# (1277, Timestamp('2003-01-01 00:00:00'))
# (1278, Timestamp('1993-01-01 00:00:00'))
# (1279, Timestamp('2009-01-01 00:00:00'))
# (1280, Timestamp('2007-01-01 00:00:00'))
# (1281, Timestamp('2010-01-01 00:00:00'))
# (1282, Timestamp('2000-01-01 00:00:00'))
# (1283, Timestamp('2012-01-01 00:00:00'))
# (1284, Timestamp('2012-01-01 00:00:00'))
# (1285, Timestamp('2010-01-01 00:00:00'))
# (1286, Timestamp('2012-01-01 00:00:00'))
# (1287, Timestamp('2006-01-01 00:00:00'))
# (1288, Timestamp('2005-01-01 00:00:00'))
# (1289, Timestamp('2012-01-01 00:00:00'))
# (1290, Timestamp('2012-01-01 00:00:00'))
# (1291, Timestamp('2010-01-01 00:00:00'))
# (1292, Timestamp('2011-01-01 00:00:00'))
# (1293, Timestamp('2010-01-01 00:00:00'))
# (1294, Timestamp('2012-01-01 00:00:00'))
# (1295, Timestamp('2001-01-01 00:00:00'))
# (1296, Timestamp('1981-01-01 00:00:00'))
# (1297, Timestamp('2012-01-01 00:00:00'))
# (1298, Timestamp('1999-01-01 00:00:00'))
# (1299, Timestamp('2011-01-01 00:00:00'))
# (1300, Timestamp('2012-01-01 00:00:00'))
# (1301, Timestamp('2010-01-01 00:00:00'))
# (1302, Timestamp('2011-01-01 00:00:00'))
# (1303, Timestamp('1988-01-01 00:00:00'))
# (1304, Timestamp('2012-01-01 00:00:00'))
# (1305, Timestamp('2012-01-01 00:00:00'))
# (1306, Timestamp('2012-01-01 00:00:00'))
# (1307, Timestamp('2011-01-01 00:00:00'))
# (1308, Timestamp('2011-01-01 00:00:00'))
# (1309, Timestamp('2010-01-01 00:00:00'))
# (1310, Timestamp('2012-01-01 00:00:00'))
# (1311, Timestamp('1994-01-01 00:00:00'))
# (1312, Timestamp('2010-01-01 00:00:00'))
# (1313, Timestamp('2012-01-01 00:00:00'))
# (1314, Timestamp('2006-01-01 00:00:00'))
# (1315, Timestamp('2012-01-01 00:00:00'))
# (1316, Timestamp('2011-01-01 00:00:00'))
# (1317, Timestamp('2013-01-01 00:00:00'))
# (1318, Timestamp('2011-01-01 00:00:00'))
# (1319, Timestamp('2012-01-01 00:00:00'))
# (1320, Timestamp('2013-01-01 00:00:00'))
# (1321, Timestamp('2009-01-01 00:00:00'))
# (1322, Timestamp('2013-01-01 00:00:00'))
# (1323, Timestamp('2010-01-01 00:00:00'))
# (1324, Timestamp('2012-01-01 00:00:00'))
# (1325, Timestamp('2010-01-01 00:00:00'))
# (1326, Timestamp('2012-01-01 00:00:00'))
# (1327, Timestamp('2013-01-01 00:00:00'))
# (1328, Timestamp('2013-01-01 00:00:00'))
# (1329, Timestamp('2008-01-01 00:00:00'))
# (1330, Timestamp('2011-01-01 00:00:00'))
# (1331, Timestamp('2009-01-01 00:00:00'))
# (1332, Timestamp('2011-01-01 00:00:00'))
# (1333, Timestamp('2012-01-01 00:00:00'))
# (1334, Timestamp('2011-01-01 00:00:00'))
# (1335, Timestamp('2013-01-01 00:00:00'))
# (1336, Timestamp('2005-01-01 00:00:00'))
# (1337, Timestamp('2008-01-01 00:00:00'))
# (1338, Timestamp('2013-01-01 00:00:00'))
# (1339, Timestamp('2010-01-01 00:00:00'))
# (1340, Timestamp('2013-01-01 00:00:00'))
# (1341, Timestamp('2013-01-01 00:00:00'))
# (1342, Timestamp('2013-01-01 00:00:00'))
# (1343, Timestamp('2012-01-01 00:00:00'))
# (1344, Timestamp('2012-01-01 00:00:00'))
# (1345, Timestamp('2012-01-01 00:00:00'))
# (1346, Timestamp('2013-01-01 00:00:00'))
# (1347, Timestamp('2013-01-01 00:00:00'))
# (1348, Timestamp('2013-01-01 00:00:00'))

# %% [markdown]
# ### is_year('1923')

# %%
if is_year(11):
    print('no one sees')

# %%
ihr.dx_date.data
# Out:
# 0                2002-01-01 00:00:00
# 1                2001-01-01 00:00:00
# 2                1997-01-01 00:00:00
# 3                2001-01-01 00:00:00
# 4                2001-01-01 00:00:00
# 5                2002-01-01 00:00:00
# 6                2002-01-01 00:00:00
# 7                2003-01-01 00:00:00
# 8                1995-01-01 00:00:00
# 9                2000-01-01 00:00:00
# 10               2001-01-01 00:00:00
# 11               2002-01-01 00:00:00
# 12               1999-01-01 00:00:00
# 13               2002-01-01 00:00:00
# 14               2002-01-01 00:00:00
# 15               2001-01-01 00:00:00
# 16               2003-01-01 00:00:00
# 17               1996-01-01 00:00:00
# 18               2002-01-01 00:00:00
# 19               2002-01-01 00:00:00
# 20               1998-01-01 00:00:00
# 21               1994-01-01 00:00:00
# 22               2001-01-01 00:00:00
# 23               2000-01-01 00:00:00
# 24               2002-01-01 00:00:00
# 25               2001-01-01 00:00:00
# 26               2001-01-01 00:00:00
# 27               2001-01-01 00:00:00
# 1274             2012-01-01 00:00:00
# 1275             2010-01-01 00:00:00
# 1276             2011-01-01 00:00:00
# 1277             2003-01-01 00:00:00
# 1278             1993-01-01 00:00:00
# 1279             2009-01-01 00:00:00
# 1280             2007-01-01 00:00:00
# 1281             2010-01-01 00:00:00
# 1282             2000-01-01 00:00:00
# 1283             2012-01-01 00:00:00
# 1284             2012-01-01 00:00:00
# 1285             2010-01-01 00:00:00
# 1286             2012-01-01 00:00:00
# 1287             2006-01-01 00:00:00
# 1288             2005-01-01 00:00:00
# 1289             2012-01-01 00:00:00
# 1290             2012-01-01 00:00:00
# 1291             2010-01-01 00:00:00
# 1292             2011-01-01 00:00:00
# 1293             2010-01-01 00:00:00
# 1294             2012-01-01 00:00:00
# 1295             2001-01-01 00:00:00
# 1296             1981-01-01 00:00:00
# 1297             2012-01-01 00:00:00
# 1298             1999-01-01 00:00:00
# 1299             2011-01-01 00:00:00
# 1300             2012-01-01 00:00:00
# 1301             2010-01-01 00:00:00
# 1302             2011-01-01 00:00:00
# 1303             1988-01-01 00:00:00
# 1304             2012-01-01 00:00:00
# 1305             2012-01-01 00:00:00
# 1306             2012-01-01 00:00:00
# 1307             2011-01-01 00:00:00
# 1308             2011-01-01 00:00:00
# 1309             2010-01-01 00:00:00
# 1310             2012-01-01 00:00:00
# 1311             1994-01-01 00:00:00
# 1312             2010-01-01 00:00:00
# 1313             2012-01-01 00:00:00
# 1314             2006-01-01 00:00:00
# 1315             2012-01-01 00:00:00
# 1316             2011-01-01 00:00:00
# 1317             2013-01-01 00:00:00
# 1318             2011-01-01 00:00:00
# 1319             2012-01-01 00:00:00
# 1320             2013-01-01 00:00:00
# 1321             2009-01-01 00:00:00
# 1322             2013-01-01 00:00:00
# 1323             2010-01-01 00:00:00
# 1324             2012-01-01 00:00:00
# 1325             2010-01-01 00:00:00
# 1326             2012-01-01 00:00:00
# 1327             2013-01-01 00:00:00
# 1328             2013-01-01 00:00:00
# 1329             2008-01-01 00:00:00
# 1330             2011-01-01 00:00:00
# 1331             2009-01-01 00:00:00
# 1332             2011-01-01 00:00:00
# 1333             2012-01-01 00:00:00
# 1334             2011-01-01 00:00:00
# 1335             2013-01-01 00:00:00
# 1336             2005-01-01 00:00:00
# 1337             2008-01-01 00:00:00
# 1338             2013-01-01 00:00:00
# 1339             2010-01-01 00:00:00
# 1340             2013-01-01 00:00:00
# 1341             2013-01-01 00:00:00
# 1342             2013-01-01 00:00:00
# 1343             2012-01-01 00:00:00
# 1344             2012-01-01 00:00:00
# 1345             2012-01-01 00:00:00
# 1346             2013-01-01 00:00:00
# 1347             2013-01-01 00:00:00
# 1348             2013-01-01 00:00:00
# Name: dx_date, Length: 1349, dtype: datetime64[ns]

# %%
pd.set_option('display.max_rows', None)

# %%
from random import randint
df = pd.DataFrame(randint(3, 8), index=['A', 'B', 'C'], columns=index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-9a4782dc0179> in <module>()
#       1 from random import randint
# ----> 2 df = pd.DataFrame(randint(3, 8), index=['A', 'B', 'C'], columns=index)
#
# NameError: name 'index' is not defined
